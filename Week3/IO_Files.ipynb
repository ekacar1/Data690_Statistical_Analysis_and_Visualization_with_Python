# %% [markdown]
# ### INPUT()

# %%
# Getting user input until the ENTER key is pressed; returns it as a string 
name = input("What's your name? ")
print("Nice to meet you " + name + "!")
# Out:
# What's your name? Jon Snow
# Nice to meet you Jon Snow!

# %% [markdown]
# ### Builtin OPEN FUNCTION

# %%
f = open("../files/text_files/bread.txt")
for line in f:
    print(line)
f.close()
# Out:
# 				Spent Grain Bread
#
#
#
# 	I got this recipe from the 1985 Grain Brewing Issue of Zymurgy magazine.  I tried it as is, and wit bananas added and found it to make a good heavy bread.  The original article is by Clifford T. Newmn Jr. and he requests any original recipies to be sent to him at P.O. Box 193, Port Matilda, PA  1680
#
#
#
# 	-4 C. fresh spent grains (from your latest batch of
#
# 	-1 C. water               all grain beer)
#
# 	-1/2 C. oil
#
# 	-1/2 C. sugar
#
# 	-1/4 tsp. salt
#
# 	-1 Tbsp. dry baker's yeast
#
# 	-All-purpose flour (enough to make a stiff dough)
#
#
#
# 	Place the spent grains and water into a blender or food processor and blend themn for 30 seconds. Ten put the blended grains in a large mixing bowl and add oil, sugar, salt and stir in the yeast. Addflour until you have a thick, workable dough. Put in a warm place to rise until doubled in size. The knead the dough and divide into three greased laof pans. Let the dough double in size again then bae in a preheated oven at 350 degrees for one hour and 15 minutes. Remove from oven and let cool on wre racks. Enjoy.
#
#
#
# 	For storing grains until ready to make the bread, place them one half inch deep in a shallow bakingdish or cookie sheet and put them into the oven at 200 degrees. Stir the grains about every half hou until they feel dry. Then store in tightly sealed containers. If you see any drops of moisture in te containers it means the grains need to be dried longer.
#
#
#
# 	Once dried, the grains will keep for a long time. They can be used dried or moist (fresh), and drie grains can be ground into flour. The recipe above is for moist (fresh) grains and if you are using ried grains, add on half cup of water for every four cups of grains in the recipe.
#
#
#
# 	I haven't tried the following recipe (yet) and am thinking of using wheat flour or flour from grain instead of white flour in my next batch of bread.
#
#
#
# 			Spent Grains Granola
#
#
#
# 	-6 C. fresh spent grains
#
# 	-4 C. raw sunflour seeds
#
# 	-2 C. weat germ
#
# 	-1 C. bran
#
# 	-1 1/2 C. non-fat dry milk
#
# 	-2 tsp. salt
#
# 	-3 Tbsp. cinnamon
#
# 	-3/4 C. molasses
#
# 	-1/2 C. honey
#
# 	-3 Tbsp. vanilla extract
#
# 	-2 C. each--coconut, raisins, chopped cashews
#
#
#
# 	Combine first seven ingredients in a large bowl and mix well. Blend molasses, honey and vanilla in  small bowl, then add to the grains, mixing well. Spreat 1/2 inch deep on a large baking pan and bak at 250 degrees until light brown, stirring occasionally. Turn onto paper-covered surface. Mix last hree ingredients and combine with granola. Store in tightly sealed containers.0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# X-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-X
#
#
#
#  Another file downloaded from:                               NIRVANAnet(tm)
#
#
#
#  & the Temple of the Screaming Electron   Jeff Hunter          510-935-5845
#
#  Rat Head                                 Ratsnatcher          510-524-3649
#
#  Burn This Flag                           Zardoz               408-363-9766
#
#  realitycheck                             Poindexter Fortran   415-567-7043
#
#  Lies Unlimited                           Mick Freen           415-583-4102
#
#
#
#    Specializing in conversations, obscure information, high explosives,
#
#        arcane knowledge, political extremism, diversive sexuality,
#
#        insane speculation, and wild rumours. ALL-TEXT BBS SYSTEMS.
#
#
#
#   Full access for first-time callers.  We don't want to know who you are,
#
#    where you live, or what your phone number is. We are not Big Brother.
#
#
#
#                           "Raw Data for Raw Nerves"
#
#
#
# X-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-X

# %% [markdown]
# ### Builtin WRITE FUNCTION

# %%
a = []
for i in range(100):
    a.append("All work and no play makes Jack a dull boy ");
f = open("anotherfile.txt", 'w')
for line in a:
    f.write(line)
f.close()

# %% [markdown]
# ### CHARACTERS

# %%
# In text files, which can be read in notepad++ etc., characters are often 
# stored in smaller 2-byte areas by code number:
ord("A")
# Out:
# 65

# %%
# Let's play with some characters!!
char = chr(8)
print("hello" + char + "world")
# Out:
# world

# %%
char = chr(7)
print("hello" + char + "world")
# Out:
# helloworld

# %%
print("hello\nworld")
# Out:
# hello
# world

# %% [markdown]
# ### MORE ON OPEN FUNCTION

# %%
f = open("../files/text_files/ex1data1.txt")
data = []
for line in f:
    parsed_line = str.split(line,",")
    data_line = []
    for word in parsed_line:
        data_line.append(float(word))
    data.append(data_line)
print(data)
f.close()
# Out:
# [[6.1101, 17.592], [5.5277, 9.1302], [8.5186, 13.662], [7.0032, 11.854], [5.8598, 6.8233], [8.3829, 11.886], [7.4764, 4.3483], [8.5781, 12.0], [6.4862, 6.5987], [5.0546, 3.8166], [5.7107, 3.2522], [14.164, 15.505], [5.734, 3.1551], [8.4084, 7.2258], [5.6407, 0.71618], [5.3794, 3.5129], [6.3654, 5.3048], [5.1301, 0.56077], [6.4296, 3.6518], [7.0708, 5.3893], [6.1891, 3.1386], [20.27, 21.767], [5.4901, 4.263], [6.3261, 5.1875], [5.5649, 3.0825], [18.945, 22.638], [12.828, 13.501], [10.957, 7.0467], [13.176, 14.692], [22.203, 24.147], [5.2524, -1.22], [6.5894, 5.9966], [9.2482, 12.134], [5.8918, 1.8495], [8.2111, 6.5426], [7.9334, 4.5623], [8.0959, 4.1164], [5.6063, 3.3928], [12.836, 10.117], [6.3534, 5.4974], [5.4069, 0.55657], [6.8825, 3.9115], [11.708, 5.3854], [5.7737, 2.4406], [7.8247, 6.7318], [7.0931, 1.0463], [5.0702, 5.1337], [5.8014, 1.844], [11.7, 8.0043], [5.5416, 1.0179], [7.5402, 6.7504], [5.3077, 1.8396], [7.4239, 4.2885], [7.6031, 4.9981], [6.3328, 1.4233], [6.3589, -1.4211], [6.2742, 2.4756], [5.6397, 4.6042], [9.3102, 3.9624], [9.4536, 5.4141], [8.8254, 5.1694], [5.1793, -0.74279], [21.279, 17.929], [14.908, 12.054], [18.959, 17.054], [7.2182, 4.8852], [8.2951, 5.7442], [10.236, 7.7754], [5.4994, 1.0173], [20.341, 20.992], [10.136, 6.6799], [7.3345, 4.0259], [6.0062, 1.2784], [7.2259, 3.3411], [5.0269, -2.6807], [6.5479, 0.29678], [7.5386, 3.8845], [5.0365, 5.7014], [10.274, 6.7526], [5.1077, 2.0576], [5.7292, 0.47953], [5.1884, 0.20421], [6.3557, 0.67861], [9.7687, 7.5435], [6.5159, 5.3436], [8.5172, 4.2415], [9.1802, 6.7981], [6.002, 0.92695], [5.5204, 0.152], [5.0594, 2.8214], [5.7077, 1.8451], [7.6366, 4.2959], [5.8707, 7.2029], [5.3054, 1.9869], [8.2934, 0.14454], [13.394, 9.0551], [5.4369, 0.61705]]

# %% [markdown]
# ### WITH

# %%
# The "with" keyword sets up a Context Manager, which temporarily deals 
# with how the code runs. This closes the file automatically when the clause is left.
# 
with open("../files/text_files/ex1data1.txt") as f:
    for line in f:
        print(line)
# Out:
# 6.1101,17.592
#
# 5.5277,9.1302
#
# 8.5186,13.662
#
# 7.0032,11.854
#
# 5.8598,6.8233
#
# 8.3829,11.886
#
# 7.4764,4.3483
#
# 8.5781,12
#
# 6.4862,6.5987
#
# 5.0546,3.8166
#
# 5.7107,3.2522
#
# 14.164,15.505
#
# 5.734,3.1551
#
# 8.4084,7.2258
#
# 5.6407,0.71618
#
# 5.3794,3.5129
#
# 6.3654,5.3048
#
# 5.1301,0.56077
#
# 6.4296,3.6518
#
# 7.0708,5.3893
#
# 6.1891,3.1386
#
# 20.27,21.767
#
# 5.4901,4.263
#
# 6.3261,5.1875
#
# 5.5649,3.0825
#
# 18.945,22.638
#
# 12.828,13.501
#
# 10.957,7.0467
#
# 13.176,14.692
#
# 22.203,24.147
#
# 5.2524,-1.22
#
# 6.5894,5.9966
#
# 9.2482,12.134
#
# 5.8918,1.8495
#
# 8.2111,6.5426
#
# 7.9334,4.5623
#
# 8.0959,4.1164
#
# 5.6063,3.3928
#
# 12.836,10.117
#
# 6.3534,5.4974
#
# 5.4069,0.55657
#
# 6.8825,3.9115
#
# 11.708,5.3854
#
# 5.7737,2.4406
#
# 7.8247,6.7318
#
# 7.0931,1.0463
#
# 5.0702,5.1337
#
# 5.8014,1.844
#
# 11.7,8.0043
#
# 5.5416,1.0179
#
# 7.5402,6.7504
#
# 5.3077,1.8396
#
# 7.4239,4.2885
#
# 7.6031,4.9981
#
# 6.3328,1.4233
#
# 6.3589,-1.4211
#
# 6.2742,2.4756
#
# 5.6397,4.6042
#
# 9.3102,3.9624
#
# 9.4536,5.4141
#
# 8.8254,5.1694
#
# 5.1793,-0.74279
#
# 21.279,17.929
#
# 14.908,12.054
#
# 18.959,17.054
#
# 7.2182,4.8852
#
# 8.2951,5.7442
#
# 10.236,7.7754
#
# 5.4994,1.0173
#
# 20.341,20.992
#
# 10.136,6.6799
#
# 7.3345,4.0259
#
# 6.0062,1.2784
#
# 7.2259,3.3411
#
# 5.0269,-2.6807
#
# 6.5479,0.29678
#
# 7.5386,3.8845
#
# 5.0365,5.7014
#
# 10.274,6.7526
#
# 5.1077,2.0576
#
# 5.7292,0.47953
#
# 5.1884,0.20421
#
# 6.3557,0.67861
#
# 9.7687,7.5435
#
# 6.5159,5.3436
#
# 8.5172,4.2415
#
# 9.1802,6.7981
#
# 6.002,0.92695
#
# 5.5204,0.152
#
# 5.0594,2.8214
#
# 5.7077,1.8451
#
# 7.6366,4.2959
#
# 5.8707,7.2029
#
# 5.3054,1.9869
#
# 8.2934,0.14454
#
# 13.394,9.0551
#
# 5.4369,0.61705

# %% [markdown]
# ### Reading multiple files

# %%
import fileinput
a = ["../files/text_files/example3.txt", 
     "../files/text_files/Genescan.txt", 
     "../files/text_files/FAME.txt"]
b = fileinput.input(a)
for line in b:
    print(b.filename())
    print(line)
b.close()
# Out:
# ../files/text_files/example3.txt
# Xanthomonas	campestris	hyacinthi	LMG739	1	5	8	4	3	2	4	1
#
# ../files/text_files/example3.txt
# Xanthomonas	campestris	campestris	LMG568	3	5	6	2	3	1	4	3
#
# ../files/text_files/example3.txt
# Xanthomonas	campestris	phaseoli	LMG803	2	4	7	4	1	2	3	2
#
# ../files/text_files/example3.txt
# Xanthomonas	campestris	hyacinthi	LMG946	2	3	6	2	1	0	1	0
#
# ../files/text_files/Genescan.txt
# Sample file	Band no.	Run time	Size	Height	Area	Run time
#
# ../files/text_files/Genescan.txt
# 15B	1	35.40	70.43	216	1111	354
#
# ../files/text_files/Genescan.txt
# 15B	2	36.90	76.86	252	1318	369
#
# ../files/text_files/Genescan.txt
# 15B	3	55.40	154.72	717	5726	554
#
# ../files/text_files/Genescan.txt
# 15B	4	62.20	183.46	120	1520	622
#
# ../files/text_files/Genescan.txt
# 15B	5	70.00	215.72	1644	12165	700
#
# ../files/text_files/Genescan.txt
# 15B	6	78.40	251.33	1113	6840	784
#
# ../files/text_files/Genescan.txt
# 15B	7	94.40	324.17	196	1141	944
#
# ../files/text_files/Genescan.txt
# 15B	8	95.20	327.98	110	730	952
#
# ../files/text_files/Genescan.txt
# 15B	9	97.50	339.02	130	678	975
#
# ../files/text_files/Genescan.txt
# 15B	10	101.80	360.01	101	387	1018
#
# ../files/text_files/Genescan.txt
# 15B	11	109.30	398.24	437	4151	1093
#
# ../files/text_files/Genescan.txt
# 15B	12	112.80	416.93	145	1511	1128
#
# ../files/text_files/Genescan.txt
# 15B	13	121.30	464.73	160	1004	1213
#
# ../files/text_files/Genescan.txt
# 15B	14	122.10	469.41	175	1186	1221
#
# ../files/text_files/Genescan.txt
# 15B	15	135.40	552.17	113	512	1354
#
# ../files/text_files/Genescan.txt
# 15B	16	136.80	561.41	150	876	1368
#
# ../files/text_files/Genescan.txt
# 15B	17	139.70	581.00	231	1585	1397
#
# ../files/text_files/Genescan.txt
# 15B	18	146.60	630.13	281	1580	1466
#
# ../files/text_files/Genescan.txt
# 15B	19	153.00	679.18	419	3926	1530
#
# ../files/text_files/Genescan.txt
# 15B	20	156.90	710.89	207	1082	1569
#
# ../files/text_files/Genescan.txt
# 15B	21	163.70	769.81	203	1377	1637
#
# ../files/text_files/Genescan.txt
# 15B	22	169.20	821.18	197	1379	1692
#
# ../files/text_files/Genescan.txt
# 15B	23	210.70		239	2766	2107
#
# ../files/text_files/Genescan.txt
# 16B	1	30.90	50.32	120	557	309
#
# ../files/text_files/Genescan.txt
# 16B	2	35.30	69.74	363	1946	353
#
# ../files/text_files/Genescan.txt
# 16B	3	36.80	76.35	169	1108	368
#
# ../files/text_files/Genescan.txt
# 16B	4	50.50	134.62	170	2053	505
#
# ../files/text_files/Genescan.txt
# 16B	5	55.30	154.84	955	8872	553
#
# ../files/text_files/Genescan.txt
# 16B	6	64.40	192.97	100	538	644
#
# ../files/text_files/Genescan.txt
# 16B	7	67.80	207.13	103	953	678
#
# ../files/text_files/Genescan.txt
# 16B	8	69.70	215.16	794	6394	697
#
# ../files/text_files/Genescan.txt
# 16B	9	78.10	251.08	1960	13690	781
#
# ../files/text_files/Genescan.txt
# 16B	10	81.60	266.33	166	1317	816
#
# ../files/text_files/Genescan.txt
# 16B	11	97.30	339.15	128	771	973
#
# ../files/text_files/Genescan.txt
# 16B	12	101.60	360.02	131	478	1016
#
# ../files/text_files/Genescan.txt
# 16B	13	109.00	397.88	233	2109	1090
#
# ../files/text_files/Genescan.txt
# 16B	14	121.00	464.69	137	1316	1210
#
# ../files/text_files/Genescan.txt
# 16B	15	136.50	561.48	314	2020	1365
#
# ../files/text_files/Genescan.txt
# 16B	16	139.30	580.42	269	2086	1393
#
# ../files/text_files/Genescan.txt
# 16B	17	152.70	679.60	180	1611	1527
#
# ../files/text_files/Genescan.txt
# 16B	18	161.50	753.53	151	925	1615
#
# ../files/text_files/Genescan.txt
# 16B	19	162.10	758.86	181	1181	1621
#
# ../files/text_files/Genescan.txt
# 16B	20	163.30	769.64	192	1580	1633
#
# ../files/text_files/Genescan.txt
# 16B	21	168.80	821.16	207	1467	1688
#
# ../files/text_files/Genescan.txt
# 17B	1	33.00	60.47	228	929	330
#
# ../files/text_files/Genescan.txt
# 17B	2	34.60	67.53	201	815	346
#
# ../files/text_files/Genescan.txt
# 17B	3	43.30	106.02	113	855	433
#
# ../files/text_files/Genescan.txt
# 17B	4	52.90	146.14	381	1908	529
#
# ../files/text_files/Genescan.txt
# 17B	5	88.20	298.95	131	690	882
#
# ../files/text_files/Genescan.txt
# 17B	6	89.00	302.68	1425	7821	890
#
# ../files/text_files/Genescan.txt
# 17B	7	155.40	709.46	304	1800	1554
#
# ../files/text_files/Genescan.txt
# 17B	8	158.50	736.00	182	966	1585
#
# ../files/text_files/Genescan.txt
# 17B	9	165.10	796.02	121	713	1651
#
# ../files/text_files/Genescan.txt
# 18B	1	33.10	61.79	197	1308	331
#
# ../files/text_files/Genescan.txt
# 18B	2	34.90	69.74	122	672	349
#
# ../files/text_files/Genescan.txt
# 18B	3	35.80	73.71	181	1062	358
#
# ../files/text_files/Genescan.txt
# 18B	4	38.30	84.74	182	902	383
#
# ../files/text_files/Genescan.txt
# 18B	5	54.80	155.01	590	3707	548
#
# ../files/text_files/Genescan.txt
# 18B	6	60.20	177.94	683	3513	602
#
# ../files/text_files/Genescan.txt
# 18B	7	69.10	215.57	440	2731	691
#
# ../files/text_files/Genescan.txt
# 18B	8	76.60	247.61	121	651	766
#
# ../files/text_files/Genescan.txt
# 18B	9	77.70	252.30	312	1761	777
#
# ../files/text_files/Genescan.txt
# 18B	10	93.20	323.82	1245	6175	932
#
# ../files/text_files/Genescan.txt
# 18B	11	94.10	328.10	261	2106	941
#
# ../files/text_files/Genescan.txt
# 18B	12	107.90	397.79	1319	11553	1079
#
# ../files/text_files/Genescan.txt
# 18B	13	120.70	470.00	802	4926	1207
#
# ../files/text_files/Genescan.txt
# 18B	14	121.90	476.99	103	995	1219
#
# ../files/text_files/Genescan.txt
# 18B	15	132.70	544.46	278	2850	1327
#
# ../files/text_files/Genescan.txt
# 18B	16	133.90	552.38	144	873	1339
#
# ../files/text_files/Genescan.txt
# 18B	17	138.10	580.89	109	734	1381
#
# ../files/text_files/Genescan.txt
# 18B	18	142.40	611.44	121	620	1424
#
# ../files/text_files/Genescan.txt
# 18B	19	143.00	615.81	179	1493	1430
#
# ../files/text_files/Genescan.txt
# 18B	20	143.80	621.69	126	744	1438
#
# ../files/text_files/Genescan.txt
# 18B	21	151.90	684.31	102	921	1519
#
# ../files/text_files/Genescan.txt
# 18B	22	153.00	693.27	128	923	1530
#
# ../files/text_files/Genescan.txt
# 18B	23	161.30	764.75	115	742	1613
#
# ../files/text_files/Genescan.txt
# 18B	24	162.10	772.03	118	751	1621
#
# ../files/text_files/Genescan.txt
# 18B	25	168.80	835.74	107	712	1688
#
# ../files/text_files/Genescan.txt
# 19B	1	31.10	53.41	100	483	311
#
# ../files/text_files/Genescan.txt
# 19B	2	33.00	61.79	175	785	330
#
# ../files/text_files/Genescan.txt
# 19B	3	34.90	70.18	1758	10330	349
#
# ../files/text_files/Genescan.txt
# 19B	4	36.40	76.79	326	3854	364
#
# ../files/text_files/Genescan.txt
# 19B	5	54.60	154.87	1066	9171	546
#
# ../files/text_files/Genescan.txt
# 19B	6	59.90	177.52	145	669	599
#
# ../files/text_files/Genescan.txt
# 19B	7	61.50	184.30	117	837	615
#
# ../files/text_files/Genescan.txt
# 19B	8	63.70	193.54	143	755	637
#
# ../files/text_files/Genescan.txt
# 19B	9	67.00	207.48	177	679	670
#
# ../files/text_files/Genescan.txt
# 19B	10	67.50	209.60	236	1682	675
#
# ../files/text_files/Genescan.txt
# 19B	11	68.90	215.57	1094	8775	689
#
# ../files/text_files/Genescan.txt
# 19B	12	74.80	240.96	173	1034	748
#
# ../files/text_files/Genescan.txt
# 19B	13	76.40	247.79	109	565	764
#
# ../files/text_files/Genescan.txt
# 19B	14	77.20	251.26	1512	9193	772
#
# ../files/text_files/Genescan.txt
# 19B	15	80.70	266.74	346	2195	807
#
# ../files/text_files/Genescan.txt
# 19B	16	88.70	303.53	128	603	887
#
# ../files/text_files/Genescan.txt
# 19B	17	96.20	339.28	441	3113	962
#
# ../files/text_files/Genescan.txt
# 19B	18	100.40	360.00	181	638	1004
#
# ../files/text_files/Genescan.txt
# 19B	19	103.10	373.81	197	1021	1031
#
# ../files/text_files/Genescan.txt
# 19B	20	107.20	395.38	308	1465	1072
#
# ../files/text_files/Genescan.txt
# 19B	21	107.70	398.06	382	3056	1077
#
# ../files/text_files/Genescan.txt
# 19B	22	111.00	416.03	902	11417	1110
#
# ../files/text_files/Genescan.txt
# 19B	23	119.50	464.64	383	3482	1195
#
# ../files/text_files/Genescan.txt
# 19B	24	134.90	561.38	443	3683	1349
#
# ../files/text_files/Genescan.txt
# 19B	25	137.70	580.27	226	1474	1377
#
# ../files/text_files/Genescan.txt
# 19B	26	142.40	613.30	102	1051	1424
#
# ../files/text_files/Genescan.txt
# 19B	27	144.50	628.63	273	1972	1445
#
# ../files/text_files/Genescan.txt
# 19B	28	150.80	676.89	1033	11980	1508
#
# ../files/text_files/Genescan.txt
# 19B	29	154.70	708.60	431	3469	1547
#
# ../files/text_files/Genescan.txt
# 19B	30	159.50	749.75	441	2729	1595
#
# ../files/text_files/Genescan.txt
# 19B	31	160.20	755.95	130	1061	1602
#
# ../files/text_files/Genescan.txt
# 19B	32	161.30	765.81	165	1384	1613
#
# ../files/text_files/Genescan.txt
# 19B	33	166.90	818.22	508	4040	1669
#
# ../files/text_files/Genescan.txt
# 19B	34	168.10	829.98	102	973	1681
#
# ../files/text_files/Genescan.txt
# 19B	35	181.70	981.57	106	1363	1817
#
# ../files/text_files/Genescan.txt
# 19B	36	182.90	996.68	307	3390	1829
#
# ../files/text_files/Genescan.txt
# 19B	37	208.00		113	1881	2080
#
# ../files/text_files/FAME.txt
# _
#
# ../files/text_files/FAME.txt
#                                                                                           DATA2:F90705633     06-JAN-95 16:29:38
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
# ID:     4632       XANT-ALBIL (LMG 482)                                           Date of run: 06-JUL-90 03:16:41
#
# ../files/text_files/FAME.txt
# Bottle: 18         SAMPLE      [AEROBE]                                           Date edited: 05-OCT-93 18:09:08
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#    RT      Area    Ar/Ht Respon     ECL           Name            %         Comment 1             Comment 2
#
# ../files/text_files/FAME.txt
# ------- --------- ------ ------   ------  -------------------- ------  --------------------  --------------------
#
# ../files/text_files/FAME.txt
#   1.733  31287000  0.062  . . .    6.997  SOLVENT PEAK . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   3.131      1399  0.033  1.210    9.999  10:0 . . . . . . . .   0.89  ECL deviates -0.001   Reference  0.002
#
# ../files/text_files/FAME.txt
#   3.522      9527  0.036  1.173   10.606  11:0 ISO . . . . . .   5.85  ECL deviates  0.001   Reference  0.004
#
# ../files/text_files/FAME.txt
#   4.724      5540  0.041  1.093   12.086  11:0 ISO 3OH . . . .   3.17  ECL deviates -0.004
#
# ../files/text_files/FAME.txt
#   6.291      2791  0.050  1.030   13.449  12:0 3OH . . . . . .   1.50  ECL deviates -0.006
#
# ../files/text_files/FAME.txt
#   7.159      4777  0.051  1.004   14.106  13:0 ISO 3OH . . . .   2.51  ECL deviates -0.004
#
# ../files/text_files/FAME.txt
#   7.918      3182  0.052  0.985   14.621  15:0 ISO . . . . . .   1.64  ECL deviates  0.000   Reference  0.000
#
# ../files/text_files/FAME.txt
#   9.360      2525  0.061  0.955   15.550  16:0 N alcohol . . .   1.26  ECL deviates  0.001
#
# ../files/text_files/FAME.txt
#   9.482     10702  0.055  0.952   15.626  16:0 ISO . . . . . .   5.34  ECL deviates -0.000   Reference -0.001
#
# ../files/text_files/FAME.txt
#   9.788     26845  0.057  0.947   15.816  16:1 w7c . . . . . .  13.30  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#  10.082     30425  0.055  0.942   15.999  16:0 . . . . . . . .  14.99  ECL deviates -0.001   Reference -0.002
#
# ../files/text_files/FAME.txt
#  10.415      1486  0.056  . . .   16.197   . . . . . . . . . .  . . .
#
# ../files/text_files/FAME.txt
#  10.787     48496  0.058  0.930   16.417  ISO 17:1 w9c . . . .  23.61  ECL deviates  0.001
#
# ../files/text_files/FAME.txt
#  11.144     35119  0.057  0.925   16.629  17:0 ISO . . . . . .  17.00  ECL deviates  0.000   Reference -0.001
#
# ../files/text_files/FAME.txt
#  11.301      8521  0.057  0.923   16.723  17:0 ANTEISO . . . .   4.11  ECL deviates  0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#  11.418      1096  0.056  0.921   16.792  17:1 w8c . . . . . .   0.53  ECL deviates  0.000
#
# ../files/text_files/FAME.txt
#  12.471      1525  0.068  0.907   17.408  17:0 10 methyl . . .   0.72  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
#  13.185      6278  0.068  0.898   17.822  Sum In Feature 7 . .   2.95  ECL deviates -0.000   18:1 w7c/w9t/w12t
#
# ../files/text_files/FAME.txt
#  13.767      1317  0.067  0.892   18.159  17:0 ISO 3OH . . . .   0.61  ECL deviates -0.005
#
# ../files/text_files/FAME.txt
# *******      6278  . . .  . . .    . . .  SUMMED FEATURE 7 . .   2.95  18:1 w7c/w9t/w12t     18:1 w9c/w12t/w7c
#
# ../files/text_files/FAME.txt
# ******* . . . . .  . . .  . . .    . . .   . . . . . . . . . .  . . .  18:1 w12t/w9t/w7c
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# Solvent Ar  Total Area  Named Area  % Named  Total Amnt  Nbr Ref  ECL Deviation  Ref ECL Shift
#
# ../files/text_files/FAME.txt
# ----------  ----------  ----------  -------  ----------  -------  -------------  -------------
#
# ../files/text_files/FAME.txt
#   31287000      201551      200065    99.26      191066        7          0.002          0.002
#
# ../files/text_files/FAME.txt
# ----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# _
#
# ../files/text_files/FAME.txt
# DATA2:F90423424     06-JAN-95 16:29:38
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
# ID:     3698       XANT-ALBIL (LMG 494)                                           Date of run: 23-APR-90 18:50:07
#
# ../files/text_files/FAME.txt
# Bottle: 62         SAMPLE      [AEROBE]
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#    RT      Area    Ar/Ht Respon     ECL           Name            %         Comment 1             Comment 2
#
# ../files/text_files/FAME.txt
# ------- --------- ------ ------   ------  -------------------- ------  --------------------  --------------------
#
# ../files/text_files/FAME.txt
#   1.499  30248000  0.060  . . .    7.048  SOLVENT PEAK . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   2.880      1598  0.030  1.163    9.999  10:0 . . . . . . . .   0.83  ECL deviates -0.001   Reference -0.004
#
# ../files/text_files/FAME.txt
#   3.273     10592  0.031  1.131   10.606  11:0 ISO . . . . . .   5.37  ECL deviates  0.001   Reference -0.003
#
# ../files/text_files/FAME.txt
#   4.486      7303  0.037  1.065   12.084  11:0 ISO 3OH . . . .   3.48  ECL deviates -0.006
#
# ../files/text_files/FAME.txt
#   6.078      2905  0.042  1.016   13.447  12:0 3OH . . . . . .   1.32  ECL deviates -0.008
#
# ../files/text_files/FAME.txt
#   6.958      5320  0.046  0.996   14.103  13:0 ISO 3OH . . . .   2.37  ECL deviates -0.007
#
# ../files/text_files/FAME.txt
#   7.732      3600  0.047  0.982   14.621  15:0 ISO . . . . . .   1.58  ECL deviates  0.000   Reference -0.001
#
# ../files/text_files/FAME.txt
#   8.297       970  0.047  0.973   15.000  15:0 . . . . . . . .   0.42  ECL deviates -0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#   9.314      5533  0.049  0.959   15.626  16:0 ISO . . . . . .   2.38  ECL deviates  0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#   9.619     28731  0.051  0.955   15.814  16:1 w7c . . . . . .  12.28  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   9.921     35103  0.051  0.951   16.000  16:0 . . . . . . . .  14.95  ECL deviates -0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#  10.249      1840  0.053  . . .   16.193   . . . . . . . . . .  . . .
#
# ../files/text_files/FAME.txt
#  10.624     61998  0.051  0.943   16.414  ISO 17:1 w9c . . . .  26.18  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
#  10.721      2854  0.056  0.942   16.471  Sum In Feature 5 . .   1.20  ECL deviates -0.005   17:1 ISO I/ANTEI B
#
# ../files/text_files/FAME.txt
#  10.991     42461  0.051  0.939   16.630  17:0 ISO . . . . . .  17.86  ECL deviates  0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#  11.147      7189  0.052  0.938   16.721  17:0 ANTEISO . . . .   3.02  ECL deviates -0.001   Reference -0.003
#
# ../files/text_files/FAME.txt
#  11.261      1629  0.053  0.937   16.788  17:1 w8c . . . . . .   0.68  ECL deviates -0.004
#
# ../files/text_files/FAME.txt
#  12.316       776  0.052  0.927   17.401  17:0 10 methyl . . .   0.32  ECL deviates -0.009
#
# ../files/text_files/FAME.txt
#  13.042      7728  0.059  0.921   17.819  Sum In Feature 7 . .   3.19  ECL deviates -0.003   18:1 w7c/w9t/w12t
#
# ../files/text_files/FAME.txt
#  13.623      1555  0.057  0.916   18.154  17:0 ISO 3OH . . . .   0.64  ECL deviates -0.010
#
# ../files/text_files/FAME.txt
#  14.451      3576  0.055  0.911   18.633  19:0 ISO . . . . . .   1.46  ECL deviates -0.000   Reference -0.003
#
# ../files/text_files/FAME.txt
#  16.800      1159  0.065  0.897   20.000  20:0 . . . . . . . .   0.47  ECL deviates  0.000   Reference -0.004
#
# ../files/text_files/FAME.txt
#  17.866      2247  0.055  . . .   20.623   . . . . . . . . . .  . . .  > max rt
#
# ../files/text_files/FAME.txt
# *******      2854  . . .  . . .    . . .  SUMMED FEATURE 5 . .   1.20  17:1 ISO I/ANTEI B    17:1 ANTEISO B/i I
#
# ../files/text_files/FAME.txt
# *******      7728  . . .  . . .    . . .  SUMMED FEATURE 7 . .   3.19  18:1 w7c/w9t/w12t     18:1 w9c/w12t/w7c
#
# ../files/text_files/FAME.txt
# ******* . . . . .  . . .  . . .    . . .   . . . . . . . . . .  . . .  18:1 w12t/w9t/w7c
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# Solvent Ar  Total Area  Named Area  % Named  Total Amnt  Nbr Ref  ECL Deviation  Ref ECL Shift
#
# ../files/text_files/FAME.txt
# ----------  ----------  ----------  -------  ----------  -------  -------------  -------------
#
# ../files/text_files/FAME.txt
#   30248000      234420      232580    99.22      223342       10          0.004          0.003
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# _
#
# ../files/text_files/FAME.txt
#                                                                                           DATA2:F92209640     11-JAN-95 15:30:33
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
# ID:     12085      XANT-ARBOR-POPUL (LMG 12141)                                   Date of run: 09-FEB-92 22:51:07
#
# ../files/text_files/FAME.txt
# Bottle: 11         SAMPLE      [AEROBE]                                           Date edited: 05-OCT-93 12:13:17
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#    RT      Area    Ar/Ht Respon     ECL           Name            %         Comment 1             Comment 2
#
# ../files/text_files/FAME.txt
# ------- --------- ------ ------   ------  -------------------- ------  --------------------  --------------------
#
# ../files/text_files/FAME.txt
#   1.656  37515000  0.075  . . .    7.004  SOLVENT PEAK . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   3.096      2008  0.032  1.125    9.999  10:0 . . . . . . . .   0.73  ECL deviates -0.001   Reference  0.006
#
# ../files/text_files/FAME.txt
#   3.499     13875  0.033  1.099   10.607  11:0 ISO . . . . . .   4.95  ECL deviates  0.002   Reference  0.008
#
# ../files/text_files/FAME.txt
#   4.129       728  0.041  1.069   11.419  10:0 3OH . . . . . .   0.25  ECL deviates -0.004
#
# ../files/text_files/FAME.txt
#   4.461      6210  0.037  1.057   11.796  unknown 11.798 . . .   2.13  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
#   4.736     10049  0.038  1.048   12.085  11:0 ISO 3OH . . . .   3.42  ECL deviates -0.005
#
# ../files/text_files/FAME.txt
#   5.122       870  0.055  1.038   12.434  11:0 3OH . . . . . .   0.29  ECL deviates -0.007
#
# ../files/text_files/FAME.txt
#   5.319      2241  0.060  1.034   12.612  13:0 ISO . . . . . .   0.75  ECL deviates -0.000   Reference  0.002
#
# ../files/text_files/FAME.txt
#   6.346      9035  0.043  1.013   13.450  12:0 3OH . . . . . .   2.97  ECL deviates -0.005
#
# ../files/text_files/FAME.txt
#   6.567      3826  0.043  1.010   13.617  14:0 ISO . . . . . .   1.25  ECL deviates -0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#   6.941      1297  0.045  1.004   13.899  Sum In Feature 1 . .   0.42  ECL deviates -0.004   14:1 w5c/14:1 w5t
#
# ../files/text_files/FAME.txt
#   7.073      6004  0.043  1.002   13.999  14:0 . . . . . . . .   1.95  ECL deviates -0.001   Reference -0.002
#
# ../files/text_files/FAME.txt
#   7.233     14999  0.044  1.000   14.105  13:0 ISO 3OH . . . .   4.87  ECL deviates -0.005
#
# ../files/text_files/FAME.txt
#   7.358      2022  0.045  0.998   14.189  13:0 2OH . . . . . .   0.65  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
#   7.694      2681  0.046  0.994   14.413  15:1 ISO F . . . . .   0.86  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#   8.009    105150  0.045  0.990   14.623  15:0 ISO . . . . . .  33.78  ECL deviates  0.002   Reference  0.001
#
# ../files/text_files/FAME.txt
#   8.144     44131  0.045  0.988   14.713  15:0 ANTEISO . . . .  14.16  ECL deviates  0.002   Reference  0.001
#
# ../files/text_files/FAME.txt
#   8.358      1814  0.047  0.986   14.855  15:1 w6c . . . . . .   0.58  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#   8.574      2293  0.046  0.983   14.999  15:0 . . . . . . . .   0.73  ECL deviates -0.001   Reference -0.002
#
# ../files/text_files/FAME.txt
#   9.598      4068  0.049  0.973   15.627  16:0 ISO . . . . . .   1.28  ECL deviates  0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#   9.838      4582  0.042  0.971   15.774  16:1 w9c . . . . . .   1.44  ECL deviates -0.000
#
# ../files/text_files/FAME.txt
#   9.906     42748  0.051  0.970   15.815  16:1 w7c . . . . . .  13.46  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
#  10.205      8235  0.050  0.967   15.999  16:0 . . . . . . . .   2.59  ECL deviates -0.001   Reference -0.004
#
# ../files/text_files/FAME.txt
#  10.915     10013  0.050  0.961   16.416  ISO 17:1 w9c . . . .   3.12  ECL deviates -0.000
#
# ../files/text_files/FAME.txt
#  11.279      8020  0.050  0.958   16.629  17:0 ISO . . . . . .   2.49  ECL deviates  0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#  11.436       838  0.053  0.956   16.722  17:0 ANTEISO . . . .   0.26  ECL deviates -0.000   Reference -0.003
#
# ../files/text_files/FAME.txt
#  11.553      1897  0.058  0.955   16.790  17:1 w8c . . . . . .   0.59  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
# *******      1297  . . .  . . .    . . .  SUMMED FEATURE 1 . .   0.42  14:1 w5t/14:1 w5c     14:1 w5c/14:1 w5t
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# Solvent Ar  Total Area  Named Area  % Named  Total Amnt  Nbr Ref  ECL Deviation  Ref ECL Shift
#
# ../files/text_files/FAME.txt
# ----------  ----------  ----------  -------  ----------  -------  -------------  -------------
#
# ../files/text_files/FAME.txt
#   37515000      309634      309634   100.00      308125       12          0.003          0.003
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# _
#
# ../files/text_files/FAME.txt
#                                                                                           DATA2:F90426403     06-JAN-95 16:29:38
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
# ID:     3764       XANT-ARBOR-CORYL (LMG 689)                                     Date of run: 26-APR-90 20:42:59
#
# ../files/text_files/FAME.txt
# Bottle: 18         SAMPLE      [AEROBE]                                           Date edited: 18-AUG-91 20:02:42
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#    RT      Area    Ar/Ht Respon     ECL           Name            %         Comment 1             Comment 2
#
# ../files/text_files/FAME.txt
# ------- --------- ------ ------   ------  -------------------- ------  --------------------  --------------------
#
# ../files/text_files/FAME.txt
#   1.506  29949000  0.060  . . .    7.039  SOLVENT PEAK . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   2.894      1405  0.029  1.175    9.999  10:0 . . . . . . . .   0.73  ECL deviates -0.001   Reference  0.002
#
# ../files/text_files/FAME.txt
#   3.289     10442  0.032  1.142   10.606  11:0 ISO . . . . . .   5.29  ECL deviates  0.001   Reference  0.003
#
# ../files/text_files/FAME.txt
#   3.905       518  0.033  1.100   11.415  10:0 3OH . . . . . .   0.25  ECL deviates -0.008
#
# ../files/text_files/FAME.txt
#   4.233      2982  0.036  1.083   11.793  unknown 11.798 . . .   1.43  ECL deviates -0.005
#
# ../files/text_files/FAME.txt
#   4.504      5430  0.037  1.070   12.083  11:0 ISO 3OH . . . .   2.58  ECL deviates -0.007
#
# ../files/text_files/FAME.txt
#   6.098      6388  0.043  1.018   13.447  12:0 3OH . . . . . .   2.89  ECL deviates -0.008
#
# ../files/text_files/FAME.txt
#   6.322      1554  0.044  1.012   13.617  14:0 ISO . . . . . .   0.70  ECL deviates -0.001   Reference  0.001
#
# ../files/text_files/FAME.txt
#   6.824      2627  0.043  1.000   13.999  14:0 . . . . . . . .   1.17  ECL deviates -0.001   Reference  0.000
#
# ../files/text_files/FAME.txt
#   6.979      9425  0.046  0.997   14.103  13:0 ISO 3OH . . . .   4.17  ECL deviates -0.007
#
# ../files/text_files/FAME.txt
#   7.104      1200  0.046  0.994   14.186  13:0 2OH . . . . . .   0.53  ECL deviates -0.005
#
# ../files/text_files/FAME.txt
#   7.755     73753  0.046  0.982   14.622  15:0 ISO . . . . . .  32.16  ECL deviates  0.001   Reference  0.002
#
# ../files/text_files/FAME.txt
#   7.889     30801  0.047  0.979   14.712  15:0 ANTEISO . . . .  13.40  ECL deviates  0.001   Reference  0.001
#
# ../files/text_files/FAME.txt
#   8.099      1239  0.049  0.976   14.852  15:1 w6c . . . . . .   0.54  ECL deviates -0.004
#
# ../files/text_files/FAME.txt
#   8.319      2279  0.049  0.972   14.999  15:0 . . . . . . . .   0.98  ECL deviates -0.001   Reference  0.000
#
# ../files/text_files/FAME.txt
#   9.337      5160  0.050  0.957   15.626  16:0 ISO . . . . . .   2.19  ECL deviates  0.000   Reference  0.000
#
# ../files/text_files/FAME.txt
#   9.573      3318  0.039  0.953   15.771  16:1 w9c . . . . . .   1.40  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   9.643     35493  0.053  0.952   15.814  16:1 w7c . . . . . .  15.01  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   9.944      7863  0.050  0.948   16.000  16:0 . . . . . . . .   3.31  ECL deviates -0.000   Reference  0.000
#
# ../files/text_files/FAME.txt
#  10.649     11127  0.053  0.940   16.415  ISO 17:1 w9c . . . .   4.64  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#  11.015     11616  0.052  0.936   16.630  17:0 ISO . . . . . .   4.83  ECL deviates  0.001   Reference  0.001
#
# ../files/text_files/FAME.txt
#  11.170       983  0.053  0.934   16.721  17:0 ANTEISO . . . .   0.41  ECL deviates -0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#  11.286      2389  0.054  0.933   16.789  17:1 w8c . . . . . .   0.99  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#  12.974       979  0.057  0.916   17.766  18:1 w9c . . . . . .   0.40  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# Solvent Ar  Total Area  Named Area  % Named  Total Amnt  Nbr Ref  ECL Deviation  Ref ECL Shift
#
# ../files/text_files/FAME.txt
# ----------  ----------  ----------  -------  ----------  -------  -------------  -------------
#
# ../files/text_files/FAME.txt
#   29949000      228971      228971   100.00      225207       11          0.004          0.001
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# _                                                                                         DATA2:F89B21603     06-JAN-95 16:29:38
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
# ID:     1709       XANT-ARBOR-JUGLA (LMG 747)                                     Date of run: 21-NOV-89 23:44:50
#
# ../files/text_files/FAME.txt
# Bottle: 13         SAMPLE      [AEROBE]
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#    RT      Area    Ar/Ht Respon     ECL           Name            %         Comment 1             Comment 2
#
# ../files/text_files/FAME.txt
# ------- --------- ------ ------   ------  -------------------- ------  --------------------  --------------------
#
# ../files/text_files/FAME.txt
#   1.506  28835000  0.057  . . .    7.032  SOLVENT PEAK . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   1.666      1294  0.022  . . .    7.361   . . . . . . . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   1.857       687  0.024  . . .    7.754   . . . . . . . . . .  . . .  < min rt
#
# ../files/text_files/FAME.txt
#   2.566       504  0.028  . . .    9.214   . . . . . . . . . .  . . .
#
# ../files/text_files/FAME.txt
#   2.948      1197  0.028  1.165   10.000  10:0 . . . . . . . .   0.67  ECL deviates -0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#   3.356      8077  0.034  1.131   10.606  11:0 ISO . . . . . .   4.39  ECL deviates  0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#   3.998       883  0.033  1.089   11.421  10:0 3OH . . . . . .   0.46  ECL deviates -0.002
#
# ../files/text_files/FAME.txt
#   4.332      3857  0.034  1.071   11.795  unknown 11.798 . . .   1.98  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   4.613      4840  0.035  1.058   12.087  11:0 ISO 3OH . . . .   2.46  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   5.007       597  0.034  1.044   12.437  11:0 3OH . . . . . .   0.30  ECL deviates -0.004
#
# ../files/text_files/FAME.txt
#   5.769       538  0.035  1.019   13.095  12:0 ISO 3OH . . . .   0.26  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   6.248      5161  0.040  1.007   13.452  12:0 3OH . . . . . .   2.50  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   6.469      1294  0.039  1.002   13.617  14:0 ISO . . . . . .   0.62  ECL deviates -0.001   Reference -0.003
#
# ../files/text_files/FAME.txt
#   6.982      1936  0.041  0.990   13.999  14:0 . . . . . . . .   0.92  ECL deviates -0.001   Reference -0.003
#
# ../files/text_files/FAME.txt
#   7.145      7357  0.042  0.987   14.107  13:0 ISO 3OH . . . .   3.49  ECL deviates -0.003
#
# ../files/text_files/FAME.txt
#   7.274      1001  0.041  0.985   14.192  13:0 2OH . . . . . .   0.47  ECL deviates  0.001
#
# ../files/text_files/FAME.txt
#   7.929     58124  0.042  0.973   14.623  15:0 ISO . . . . . .  27.16  ECL deviates  0.002   Reference -0.000
#
# ../files/text_files/FAME.txt
#   8.064     34966  0.043  0.971   14.712  15:0 ANTEISO . . . .  16.30  ECL deviates  0.001   Reference -0.001
#
# ../files/text_files/FAME.txt
#   8.281      1680  0.043  0.967   14.855  15:1 w6c . . . . . .   0.78  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#   8.502      3016  0.045  0.964   15.000  15:0 . . . . . . . .   1.40  ECL deviates  0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#   9.533      6546  0.046  0.951   15.626  16:0 ISO . . . . . .   2.99  ECL deviates  0.000   Reference -0.002
#
# ../files/text_files/FAME.txt
#   9.774      3171  0.041  0.948   15.773  16:1 w9c . . . . . .   1.44  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#   9.845     31350  0.047  0.947   15.816  16:1 w7c . . . . . .  14.26  ECL deviates -0.001
#
# ../files/text_files/FAME.txt
#  10.146      6235  0.046  0.944   15.998  16:0 . . . . . . . .   2.83  ECL deviates -0.002   Reference -0.004
#
# ../files/text_files/FAME.txt
#  10.861     12805  0.047  0.937   16.416  ISO 17:1 w9c . . . .   5.76  ECL deviates -0.000
#
# ../files/text_files/FAME.txt
#  11.228     13904  0.048  0.934   16.630  17:0 ISO . . . . . .   6.23  ECL deviates  0.001   Reference -0.003
#
# ../files/text_files/FAME.txt
#  11.386      1886  0.049  0.933   16.722  17:0 ANTEISO . . . .   0.84  ECL deviates -0.000   Reference -0.003
#
# ../files/text_files/FAME.txt
#  11.506      3316  0.051  0.932   16.792  17:1 w8c . . . . . .   1.48  ECL deviates -0.000
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# Solvent Ar  Total Area  Named Area  % Named  Total Amnt  Nbr Ref  ECL Deviation  Ref ECL Shift
#
# ../files/text_files/FAME.txt
# ----------  ----------  ----------  -------  ----------  -------  -------------  -------------
#
# ../files/text_files/FAME.txt
#   28835000      214241      213737    99.76      208252       11          0.002          0.003
#
# ../files/text_files/FAME.txt
# -----------------------------------------------------------------------------------------------------------------
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
#
#
# ../files/text_files/FAME.txt
# _

# %% [markdown]
# # FILE TYPES

# %% [markdown]
# ### WORKING WITH CSV FILES

# %%
import csv
f = open('../files/csv_files/csv_plain_file.csv', newline='')
reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
for row in reader: # A list of rows
    for value in row: # A list of value
        print(value) # Floats
f.close() # Don't close until you are done with the reader;
# Out:
# 10,10,50,50,10
# 10,50,50,10,10
# 25,25,75,75,25
# 25,75,75,25,25
# 50,50,100,100,50
# 50,100,100,50,50

# %%
import csv
with open('../files/csv_files/addresses.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    firstnames, lastnames, streets, citys, states,zipcodes = [], [], [],[], [], []
        
    for row in readCSV:
        firstname, lastname, street = row[0], row[1], row[2] 
        city, state, zipcode  = row[3], row[4], row[5]  

        firstnames.append(firstname)
        lastnames.append(lastname)
        zipcodes.append(zipcode)

    print(firstnames)
    print(lastnames)
    print(zipcodes)
# Out:
# ['John', 'Jack', 'John "Da Man"', 'Stephen', '', 'Joan "the bone", Anne']
# ['Doe', 'McGinnis', 'Repici', 'Tyler', 'Blankman', 'Jet']
# [' 08075', '09119', '08075', ' 91234', ' 00298', '00123']

# %%
import csv
f = open('../files/csv_files/plain_csv_file.csv', newline='') 
reader = csv.reader(f, quoting=csv.QUOTE_NONNUMERIC)
for row in reader: # A list of rows
    for value in row: # A list of value
        print(value) # Floats
f.close() # Don't close until you are done with the reader;
          # the data is read on request.
# Out:
# 1.0
# 2222.0
# 3.0
# 3.5
# 32312.0
# 1981.0
# 250000.0
# 2.0
# 1628.0
# 3.0
# 2.0
# 32308.0
# 2009.0
# 185000.0
# 3.0
# 3824.0
# 5.0
# 4.0
# 32312.0
# 1954.0
# 399000.0
# 4.0
# 1137.0
# 3.0
# 2.0
# 32309.0
# 1993.0
# 150000.0
# 5.0
# 3560.0
# 6.0
# 4.0
# 32309.0
# 1973.0
# 315000.0
# 6.0
# 2893.0
# 4.0
# 3.0
# 32312.0
# 1994.0
# 699000.0
# 7.0
# 3631.0
# 4.0
# 3.0
# 32309.0
# 1996.0
# 649000.0
# 8.0
# 2483.0
# 4.0
# 3.0
# 32312.0
# 2016.0
# 399000.0
# 9.0
# 2400.0
# 4.0
# 4.0
# 32312.0
# 2002.0
# 613000.0
# 10.0
# 1997.0
# 3.0
# 3.0
# 32311.0
# 2006.0
# 295000.0
# 11.0
# 2097.0
# 4.0
# 3.0
# 32311.0
# 2016.0
# 290000.0
# 12.0
# 3200.0
# 5.0
# 4.0
# 32312.0
# 1964.0
# 465000.0
# 13.0
# 4892.0
# 5.0
# 6.0
# 32311.0
# 2005.0
# 799900.0
# 14.0
# 1128.0
# 2.0
# 1.0
# 32303.0
# 1955.0
# 89000.0
# 15.0
# 1381.0
# 3.0
# 2.0
# 32301.0
# 2006.0
# 143000.0
# 16.0
# 4242.0
# 4.0
# 5.0
# 32303.0
# 2007.0
# 569000.0
# 17.0
# 2533.0
# 3.0
# 2.0
# 32310.0
# 1991.0
# 365000.0
# 18.0
# 1158.0
# 3.0
# 2.0
# 32303.0
# 1993.0
# 155000.0
# 19.0
# 2497.0
# 4.0
# 4.0
# 32309.0
# 1990.0
# 289000.0
# 20.0
# 4010.0
# 5.0
# 3.0
# 32309.0
# 2002.0
# 549900.0

# %%
# let's create a new csv file from an existing one
# new file will contain only the information that we want/need
import csv
f2 = open('dataout1.csv', 'w', newline='') 
writer = csv.writer(f2, delimiter=',')

with open('../files/csv_files/addresses.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    firstnames, lastnames, streets, citys, states,zipcodes = [], [], [],[], [], []
        
    for row in readCSV:
        firstname, lastname, street = row[0], row[1], row[2] 
        city, state, zipcode  = row[3], row[4], row[5]
        data2write = (firstname,lastname,state)
        print(data2write)
        writer.writerow(data2write)
        
    f2.close()
# Out:
# ('John', 'Doe', ' NJ')
# ('Jack', 'McGinnis', ' PA')
# ('John "Da Man"', 'Repici', ' NJ')
# ('Stephen', 'Tyler', 'SD')
# ('', 'Blankman', ' SD')
# ('Joan "the bone", Anne', 'Jet', 'CO')

# %%
# Let's read csv and write txt
import csv

with open('../files/csv_files/addresses.csv') as csvfile:
    f2 = open("textout.txt", "w")

    readCSV = csv.reader(csvfile, delimiter=',')
    firstnames, lastnames, streets, citys, states,zipcodes = [], [], [],[], [], []
        
    for row in readCSV:
        firstname, lastname, street = row[0], row[1], row[2] 
        city, state, zipcode  = row[3], row[4], row[5]
        text2write = firstname+' lives in '+ city +', '+state
        print(text2write)
        f2.write(text2write+'\n')
        
    f2.close()
# Out:
# John lives in Riverside,  NJ
# Jack lives in Phila,  PA
# John "Da Man" lives in Riverside,  NJ
# Stephen lives in SomeTown, SD
#  lives in SomeTown,  SD
# Joan "the bone", Anne lives in Desert City, CO

# %% [markdown]
# ### JSON FILES

# %%
# Writing JSON to a FILE

# %%
import json

data = {}  
data['people'] = []  
data['people'].append({  
    'name': 'Scott',
    'website': 'umbc.edu',
    'from': 'Maryland'
})
data['people'].append({  
    'name': 'Larry',
    'website': 'google.com',
    'from': 'Michigan'
})
data['people'].append({  
    'name': 'Tim',
    'website': 'apple.com',
    'from': 'Alabama'
})

with open('./outputs/json_data.txt', 'w') as outfile:  
    json.dump(data, outfile)

# %%
# Reading JSON from a TXT File

import json

with open('./outputs/json_data.txt') as json_file:  
    data = json.load(json_file)
    for p in data['people']:
        print('Name: ' + p['name'])
        print('Website: ' + p['website'])
        print('From: ' + p['from'])
        print('')
# Out:
# Name: Scott
# Website: umbc.edu
# From: Maryland
#
# Name: Larry
# Website: google.com
# From: Michigan
#
# Name: Tim
# Website: apple.com
# From: Alabama

# %%
# JSON Read
import json
f = open('../files/json_files/geo_data.json')
data = json.load(f)
f.close()    
print(data)
print('____________________________________')
print(data["features"])
print('____________________________________')
print(data["features"][0]["geometry"])
print('____________________________________')
for i in data["features"]:
    print(i["geometry"]["coordinates"][0])
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [42.0, 21.0]}, 'properties': {'prop0': 'value0'}}]}
# ____________________________________
# [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [42.0, 21.0]}, 'properties': {'prop0': 'value0'}}]
# ____________________________________
# {'type': 'Point', 'coordinates': [42.0, 21.0]}
# ____________________________________
# 42.0

# %% [markdown]
# ## Operating System

# %%
import os
print(os.environ["PATH"])
# Out:
# /Users/ergun/anaconda3/bin:/Library/Frameworks/Python.framework/Versions/3.7/bin:/Library/Frameworks/Python.framework/Versions/3.5/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Frameworks/Python.framework/Versions/3.5:/opt/X11/bin:/Library/TeX/texbin
# /Users/ergun

# %%
print(os.environ["HOME"])
# Out:
# /Users/ergun

# %%
# Current working directory.
os.getcwd()
# Out:
# '/Users/ergun/Google Drive/DS/Python_Class/ErgunClass/05_Python_IO'

# %%
# List of everything in the present directory.
os.listdir(path='.')
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'JB_Fundamentals04_IO.ipynb',
#  'JNB_OS_Files.ipynb',
#  'outputs',
#  'Python_IO.pptx',
#  'temp',
#  'www_JNB_OS_Files.html',
#  '~$Python_IO.pptx']

# %%
# run the command mkdir (make a directory) in the system shell
os.system('mkdir test_folder')
# Out:
# 0

# %%
# list everything in the present directory
os.listdir(path='.')
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'JB_Fundamentals04_IO.ipynb',
#  'JNB_OS_Files.ipynb',
#  'outputs',
#  'Python_IO.pptx',
#  'temp',
#  'test_folder',
#  'www_JNB_OS_Files.html',
#  '~$Python_IO.pptx']

# %%
# now we have a new folder called "test_folder". let's go into that directory
os.chdir('./test_folder/')

# %%
os.getcwd()
# Out:
# '/Users/ergun/Google Drive/DS/Python_Class/ErgunClass/05_Python_IO/test_folder'

# %%
# let's go back to previous folder
os.chdir('./..')
os.getcwd()
# Out:
# '/Users/ergun/Google Drive/DS/Python_Class/ErgunClass/05_Python_IO'

# %%
os.system('mkdir test_folder2')
# Out:
# 0

# %%
# let's create a folder inside the test_folder2
os.system('mkdir test_folder2/test_subfolder1')
# Out:
# 0

# %%
# let's list subdirectories
import pathlib
p = pathlib.Path('.') # current directory
for x in p.iterdir():
    if x.is_dir():
        print(x)
# Out:
# .ipynb_checkpoints
# outputs
# temp
# test_folder
# test_folder2

# %%
# CREATING A FILE AT CURRENT DIRECTORY
f = open('test_file.txt',"w+")

# %%
# WRITING IN A FILE
for x in range(10):
    f.write("This is line %d\r\n" % (x+1))

# %%
# CLOSING A FILE
f.close()

# %%
# OPENING AN EXISTING FILE AND APPENDING IT
g = open("test_file.txt","+a")

# %%
for x in range(5):
    g.write("Appended line %d\r\n" % (x+1))

# %%
g.close()

# %%
# READING A LOCAL FILE
with open('test_file.txt','r') as h:
    for line in h:
        print(line.rstrip('\n'))
# Out:
# This is line 1
# This is line 2
# This is line 3
# This is line 4
# This is line 5
# This is line 6
# This is line 7
# This is line 8
# This is line 9
# This is line 10
# Appended line 1
# Appended line 2
# Appended line 3
# Appended line 4
# Appended line 5

# %%
# Let's list all the txt files in this folder and subfolders
import glob
glob.glob('**/*.txt', recursive=True)
# Out:
# ['test_file.txt',
#  'outputs/anotherfile.txt',
#  'outputs/json_data.txt',
#  'outputs/textout.txt']

# %% [markdown]
# ### Accessing online files

# %%
import requests

# %%
import csv
CSV_URL = 'http://samplecsvs.s3.amazonaws.com/Sacramentorealestatetransactions.csv'

# %%
with requests.Session() as s:
    download = s.get(CSV_URL)
#
    decoded_content = download.content.decode('utf-8')
#
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    for row in my_list:
        print(row)
# Out:
# ['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type', 'sale_date', 'price', 'latitude', 'longitude']
# ['3526 HIGH ST', 'SACRAMENTO', '95838', 'CA', '2', '1', '836', 'Residential', 'Wed May 21 00:00:00 EDT 2008', '59222', '38.631913', '-121.434879']
# ['51 OMAHA CT', 'SACRAMENTO', '95823', 'CA', '3', '1', '1167', 'Residential', 'Wed May 21 00:00:00 EDT 2008', '68212', '38.478902', '-121.431028']
# ['2796 BRANCH ST', 'SACRAMENTO', '95815', 'CA', '2', '1', '796', 'Residential', 'Wed May 21 00:00:00 EDT 2008', '68880', '38.618305', '-121.443839']
# ['2805 JANETTE WAY', 'SACRAMENTO', '95815', 'CA', '2', '1', '852', 'Residential', 'Wed May 21 00:00:00 EDT 2008', '69307', '38.616835', '-121.439146']
# ['6001 MCMAHON DR', 'SACRAMENTO', '95824', 'CA', '2', '1', '797', 'Residential', 'Wed May 21 00:00:00 EDT 2008', '81900', '38.51947', '-121.435768']
# ['5828 PEPPERMILL CT', 'SACRAMENTO', '95841', 'CA', '3', '1', '1122', 'Condo', 'Wed May 21 00:00:00 EDT 2008',
text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#
# <title>Data Science at UMBC</title>
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
# <meta name="description" content="The Data Science Master’s program at UMBC prepares students from a wide range of disciplinary backgrounds for careers in data science." />
#
# <!--- Google Analytics --->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-1756263-56', 'auto');
#   ga('create', 'UA-1756263-52', 'auto', {'name': 'rollup'});
#   ga('create', 'UA-1045586-1', 'auto', {'name': 'umbc'});
#   ga('require', 'displayfeatures');
#   ga('require', 'linkid', 'linkid.js');
#   ga('send', 'pageview');
#   ga('rollup.send', 'pageview');
#
# </script>
#
#
# <!-- Google Code for Remarketing Tag -->
# <script type="text/javascript" src="//www.googleadservices.com/pagead/conversion.js">
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 1059307789;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
#
# <noscript>
# <div style="display:inline;"> <img height="1" width="1" style="border-style:none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1059307789/?value=0&amp;guid=ON&amp;script=0"/> </div>
# </noscript>
#
#
# <!-- Google Tag Manager -->
# <noscript>
# <iframe src="//www.googletagmanager.com/ns.html?id=GTM-WNFLMS4"
# height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W9H97S5');</script>
# <!-- End Google Tag Manager -->
#
#
# <!-- Google Tag Manager (Rollup)-->
# <noscript>
# <iframe src="//www.googletagmanager.com/ns.html?id=GTM-WRJMP6"
# height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WRJMP6');</script>
# <!-- End Google Tag Manager -->
#
#
# <!-- Bing Tracking Code -->
# <script>
# (function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"5013621"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");
# </script>
# <noscript>
# <img src="//bat.bing.com/action/0?ti=5013621&Ver=2" height="0" width="0" style="display:none; visibility: hidden;" />
# </noscript>
#
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '474030342731967');
# fbq('track', "PageView");</script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=474030342731967&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
#
#
# <!--- Twitter Code for Remarketing Tag --->
# <script src="//platform.twitter.com/oct.js" type="text/javascript"></script>
# <script type="text/javascript">
# twttr.conversion.trackPid('l4pxn');
# </script>
# <noscript>
# <img height="1" width="1" style="display:none;" alt="" src="https://analytics.twitter.com/i/adsct?txn_id=l4pxn&p_id=Twitter" /> <img height="1" width="1" style="display:none;" alt="" src="//t.co/i/adsct?txn_id=l4pxn&p_id=Twitter" />
# </noscript>
# <!---------------------------------------->
#
#
#
#
# <!---------------------HOT JAR---------------->
# <!-- Hotjar Tracking Code for http://datascience.umbc.edu -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:764063,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script>
#
#
# <!---------------PARDOT ---------------------->
# <script type="text/javascript">
# piAId = '376302';
# piCId = '79286';
# piHostname = 'pi.pardot.com';
#
# (function() {
# 	function async_load(){
# 		var s = document.createElement('script'); s.type = 'text/javascript';
# 		s.src = ('https:' == document.location.protocol ? 'https://pi' : 'http://cdn') + '.pardot.com/pd.js';
# 		var c = document.getElementsByTagName('script')[0]; c.parentNode.insertBefore(s, c);
# 	}
# 	if(window.attachEvent) { window.attachEvent('onload', async_load); }
# 	else { window.addEventListener('load', async_load, false); }
# })();
# </script>
#
#
#
#
# <!-- Siteimprove -->
# <script type="text/javascript">
# /*<![CDATA[*/
# (function() {
# var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# sz.src = '//siteimproveanalytics.com/js/siteanalyze_49841.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# })();
# /*]]>*/
# </script>
# <!-- Twitter Card data -->
# <meta name="twitter:card" value="summary">
# <meta name="twitter:site" content="@UMBC_DPS">
#
# <!-- Open Graph data -->
# <meta property="og:title" content="Data Science at UMBC" />
# <meta property="og:type" content="article" />
# <meta property="og:url" content="http://www.umbc.edu/datascience/index/" />
# <meta property="og:image" content="http://www.umbc.edu/biotech/images/bk.jpg" />
# <meta property="og:description" content="The Data Science Master’s program at UMBC prepares students from a wide range of disciplinary backgrounds for careers in data science." />
#
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport">
#   <link href='http://fonts.googleapis.com/css?family=Open+Sans:400,600,700' rel='stylesheet' type='text/css'>  <link href='css/magnific-popup.css' rel='stylesheet'>
#   <link href="css/styles.css" rel="stylesheet">
#   <script src="js/modernizr.custom.js"></script>
#   <link href="images/favicon.ico" rel="shortcut icon">
#   <link href="images/apple-touch-icon.png" rel="apple-touch-icon">
#   <link href="images/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72">
#   <link href="images/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114">
#
# <link href='http://umbc.edu/dps/css/sf-request-info.css' rel='stylesheet'>
# </head>
#
#
# <body>
#   <div id="skip-content">
#     <a href="#main-content">Skip to Main Content</a>
#   </div>
#   <!-- main container -->
#
#
#   <div id="container-header-background">
#     <!-- umbc header -->
#
#
#     <div id="container-header">
#       <header id="umbc-header">
#   <div id="umbc-logo">
#     <a href="http://umbc.edu" title="UMBC: An Honors University in Maryland"><span>UMBC: An Honors University in Maryland</span></a>
#   </div>
#
#
#   <nav id="umbc-nav">
#     <ul id="umbc-nav-items">      <li id="umbc-nav-50">
#         <a href="http://umbc.edu">UMBC</a>
#       </li>
#
#       <li id="umbc-nav-azindex">
#         <a href="http://umbc.edu/siteindex">A-Z Index</a>
#       </li>
#
#
#       <li id="umbc-nav-myumbc">
#         <a href="http://my.umbc.edu">myUMBC</a>
#       </li>
#
#
#       <li id="umbc-nav-events">
#         <a href="http://my.umbc.edu/events">Events</a>
#       </li>
#
#
#       <li id="umbc-nav-directory">
#         <a href="http://umbc.edu/search/directory">Directory</a>
#       </li>
#
#
#       <li id="umbc-nav-maps">
#         <a href="http://about.umbc.edu/visitors-guide/campus-map">Maps</a>
#       </li>
#     </ul>
#
#
#     <form action="http://www.umbc.edu/stats/searchthru/" id="umbc-nav-search" method="get" name="umbc-nav-search">
#       <div id="umbc-nav-search-input">
#         <label for="umbc-nav-search-query">Search UMBC</label> <input name="cx" type="hidden" value="008589878477221853669:fglxypz-c8m"> <input name="ie" type="hidden" value="UTF-8"> <input autocomplete="off" id="umbc-nav-search-query" maxlength="250" name="q" placeholder="Search" size="250" type="text"> <input id="umbc-nav-search-submit" type="submit" value="">
#       </div>
#     </form>
#   </nav>
# </header>
#
#
# <header id="site-header">
#   <a href="#" id="mobile-site-menu-expander"><span class="mobile-site-menu-expander-bar"></span> <span class="mobile-site-menu-expander-bar"></span> <span class="mobile-site-menu-expander-bar"></span></a>
# </header>    </div>
#     <!-- END umbc header -->
#     <!-- gold toolbar -->
#
#
#     <div id="site-menu-background">
#       <nav id="site-menu">
#   <ul class="menu" id="menu-main">
#     <li>
#       <a href="index.php">Home</a>
#     </li>
#
#
#
#     <li>
#       <a href="programcert.php">Program Info</a>
#       <ul class="sub-menu">
#         <li><a href="programmaster.php">Master's</a></li>
#         <li><a href="programcert.php">Certificate</a></li>
# 		  <li><a href="programbsmps.php">Accelerated BS/MPS</a></li>
#
#         <li>
#           <a href="costs.php">Program Costs</a>
#         </li>
#
#         <li>
#           <a href="courses.php">Course Descriptions</a>
#         </li>
#
#         <li>
#           <a href="schedule.php">Schedule of Classes</a>
#         </li>
#       </ul>
#     </li>
#
#     <li>
#       <a href="faculty.php">Faculty</a>
#     </li>
#     <li>
#       <a href="masters.php">How to Apply</a>
#       <ul class="sub-menu">
#         <li><a href="masters.php">Master's & Certificate</a></li>
#         <li><a href="international.php">International</a></li>
#         <li><a href="programbsmps.php">Accelerated BS/MPS</a></li>
#       </ul>
#     </li>
#     <li><a href="studentresources.php">Resources</a>
#       <ul class="sub-menu">
#         <li><a href="studentforms.php">Forms</a></li>
#         <li><a href="studentresources.php">Student Resources</a></li>
#       </ul>
#     </li>
#
#     <li> <a href="locations.php">Locations</a>
#       <ul class="sub-menu">
#         <li><a href="http://about.umbc.edu/visitors-guide/directions/" target="_blank">UMBC Campus (Catonsville, MD)</a></li>
#         <li> <a href="directions.php">UMBC BW Tech South</a></li>
#       </ul>
#     </li>
#
#     <li>
#       <a href="contact.php">Contact Us</a>
#     </li>
#   </ul>
# </nav>    </div>
#     <!-- END gold toolbar -->
#   </div>
#   <!-- BEGIN MAIN -->
#   <!-- Page Header -->
#     <div class="container column">
#     <div class="sixteen columns">
#       <h1 class="home-header" id="dps" style="border:0;"><a href="index.php" id="breadcrumb"><img alt="Data Science" class="scale-with-grid" src="images/logo.png"></a>
#       <div align="center" style="border-top:2px #E9AB13 solid"></div>
#       </h1>
#     </div>  <!-- END Page Header -->
#
#
#   <div class="eleven columns">
#     <div class="cbp-fwslider" id="cbp-fwslider">
#       <ul>
#
# <!-- EVENT SLIDE -->
#
#
# <!-- SLIDE ONE -->
#
#
#
# <!-- END SLIDE ONE -->
# <li id="slide1">
#
# <a href="https://gradschool.umbc.edu/admissions/apply/"><img src="http://cyber.umbc.edu/images/1.jpg" alt="RSVP to our Open House"/></a>
#
# <div class="carousel-caption wordwrap">
# 	  <h3>Now Accepting Applications</h3>
# 	  <small>Apply now for Fall 2019</small>
#
# 	  <p><a href="http://gradschool.umbc.edu/admissions/apply" target="_blank" class="web-seemore">Apply Now</a></p></div>
#
# 	  <p id="captionthree"><a href="http://gradschool.umbc.edu/admissions/apply" target="_blank">Now Accepting Applications</a></p>
#
# </li>
#
#
#
#
# 	<!-- Slide 2 -->
#
#
#
#
#
# <li id="slide2">
#
# <a href="https://www.youtube.com/watch?v=rAe6FbE3jb0" class="video"><img src="http://www.umbc.edu/cyber/images/2.jpg" alt="Learn more about our Data Science program"/></a>
#
# <div class="carousel-caption-right wordwrap">
# <h3>Data Science: A High Demand Career</h3>
# <small>Find out how a degree in Data Science can get you where you want to be.</small>
#
# <p><a href="https://www.youtube.com/watch?v=rAe6FbE3jb0" class="web-seemore video">Watch Now</a></p></div>
#
# <p id="captionone">
# <a href="https://www.youtube.com/watch?v=rAe6FbE3jb0" class="video">Data Science: A High Demand Career</a></p>
#
# </li>
# <li id="slide3">
#
# <a href="http://gritinaction.umbc.edu/mps-degree/" target="_blank">
# <img src="https://engm.umbc.edu/images/4.png" alt="UMBC Regional Tuition Rate"/>
# </a>
#
# <div class="carousel-caption wordwrap">
# <h3>What Exactly is an MPS Degree?</h3>
# <small>MPS degree programs go far beyond technical skills and theoretical knowledge</small>
#
# <p><a href="http://gritinaction.umbc.edu/mps-degree/" role="button" class="web-seemore" target="_blank">Read More</a></p></div>
#
#
# <p id="captionthree"><a href="http://gritinaction.umbc.edu/mps-degree/" target="_blank">What Exactly is an MPS Degree?</a></p>
#
# </li>
#
# 		  </ul>
#
# <!-- End Slide 2 -->
#
#
#
#       <div id="dotcontainer">
#       </div>
#     </div>
#     <!-- START Content -->
#
#
#     <h3>UMBC Data Science Graduate Programs</h3>
#
#
#        <p>The Data Science graduate program at UMBC prepares students to respond to the growing demand for professionals with data science knowledge, skills, and abilities. Our program brings together faculty from a wide range of fields who have a deep understanding of the real-world applications of data analytics. UMBC’s Data Science programs prepare students to excel in data science roles through hands-on experience, rigorous academics, and access to a robust network of knowledgeable industry professionals. </p>
#
# <p>These programs were designed with working professionals in mind and offer courses in the evening and online to accommodate students with full-time jobs. With two campuses in Baltimore and Rockville, students can choose the location that best suits their needs. UMBC offers a 10-course <a href="programmaster.php">Data Science Master&rsquo;s program</a> (M.P.S. in Data Science) as well as a 4-course <a href="programcert.php">post-baccalaureate certificate in Data Science</a>.</p>
#
# <p>Through our program, students will develop an in-depth understanding of the basic computing principles behind data science, including data ingestion, curation, and cleaning.
# </p>
#
# <p>Our unique program pathways allow students to apply the principles of data science to the analysis of problems across domains. Upon completion of their degree, students will be able to demonstrate the kind of practical, industry-relevant experience that employers are seeking.</p>
#
# <h3>Why Data Science at UMBC?</h3>
# <p>The Data Science graduate programs at UMBC prepare students from a wide range of disciplinary backgrounds for careers in data science. In the core courses, students will gain a thorough understanding of data science through classes that highlight machine learning, data analysis, data management, ethical and legal considerations, and more. There are many benefits to the Data Science graduate program at UMBC, including:</p>
# <ul>
# 	<li>Our small classes provide a mix of in-person and online instruction, giving students the best of an in-classroom experience while allowing for work-school-life balance</li>
#
# 	<li>Two campus location in Catonsville and Rockville offer convenience and proximity to the national job hubs of Downtown Baltimore and Washington, D.C.</li>
#
# 	<li>As industry experts, our faculty combine their professional experience with theory to provide a rigorous and relevant classroom experience as well as valuable networking opportunities</li>
#
# 	<li>Organizations have a growing need for employees who are experts in the management and interpretation of big data. Our program prepares students for success in these highly in-demand jobs</li>
# 	<li>As a public university, we are able to offer a top-notch program that is affordable and accessible. Students living in select areas in the Mid Atlantic region may also qualify for our <a href="http://regional.umbc.edu">regional graduate tuition rate</a> </li>
#
# </ul>
#
#
# <h3>What is an MPS Degree?</h3>
# 	  <p>The MPS in Data Science is an industry-recognized credential. The program prepares students with the technical and management skills that they need to succeed in the workplace.</p>
# 	  <p>An<a href="http://gritinaction.umbc.edu/mps-degree/"> MPS degree</a> is designed to provide you with practical and applied knowledge in your area of study. While traditional master&rsquo;s programs tend to focus on theory and research, a Master&rsquo;s of Professional Studies will equip you with specialized skills and hands-on learning opportunities with a focus on career development.</p>
# 	  <br>
# 	  <p>UMBC’s graduate programs are designed with your career goals in mind.</p>
#
#
#
#     <!-- END Content -->
#
#
#   </div>
#   <!-- SIDEBAR -->
#   <div class="five columns">
#
#
#
#
#
#  <aside class="five columns add-bottom" id="two">
#       <h3 style="color:#fff;">Upcoming Event</h3>
#       <p style="text-align:center">
# <strong>Join us for our Open House</strong><br />
# Shady Grove: Wednesday, June 19
#
# <a class="btn" href="http://openhouse.umbc.edu/shadygrove?utm_campaign=openhouse_summer19&utm_source=umbc.edu&utm_medium=referral&utm_content=datascience_sidebar">Reserve your spot</a>
#       </p>
#     </aside>
# <aside class="five columns add-bottom" id="three">
#        <h3 style="color:#fff;">Application Deadline</h3>
#
#
#  <p style="text-align:center">
# <strong>Apply Now for Fall 2019</strong><br>
# Classes Begin August 28th
#         <a class="btn" href="http://gradschool.umbc.edu/admissions/apply">Apply Now</a>
#       </p>
# </aside>
#
#     <aside class="five columns add-bottom" id="three">
#       <h3 style="color:#fff;">At a Glance</h3>
#
#
#       <dl>
#         <dt>Location Offered</dt>
#
#
#         <dd>Catonsville &amp; <a href="http://shadygrove.umbc.edu/datascience">Rockville</a> </dd>
#
#         <dt>Programs Offered</dt>
#
#
#         <dd>Master’s in Professional Studies: Data Science; Graduate Certificate in Professional Studies: Data Science</dd>
#
#
#         <dt>Estimated Completion Time</dt>
#
#
#         <dd>
#         Up to 3 Years (Part Time)</dd>
#         <dd>Up to 2 Years (Full Time)</dd>
#
#
#         <dt>Credit Hours</dt>
#         <dd>30 - Master's </dd>
#         <dt>Tuition &amp; Fees <span style="font-size:8.5pt">(MD/<a href="http://regional.umbc.edu" target="_blank">Regional</a> Resident)</span></dt>
#         <dd>$799 per credit</dd>
#
#
#         <dt>Tuition &amp; Fees (Non-MD Resident)</dt>
#
#
#         <dd>$1,272 per credit</dd>
#
#
#
#         <dt>Start Date</dt>
#
#
#         <dd>Spring/Fall</dd>
#
#                 <dt style="text-align:center"><a class="btn" href="documents/programguide.pdf" target="_blank">Download Program Guide PDF</a></dt>
#       </dl>
#     </aside>
#
#
# <aside class="five columns add-bottom" id="four">
# 	<h3 style="color:#fff;">Request Information</h3>
#
# 	<div id="form">
#
# 	<!-- FORM: HEAD SECTION -->
#
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#                         <style>
#                     .captcha {
#                         padding-bottom: 1em !important;
#                     }
#                     .wForm .captcha .oneField {
#                         margin: 0;
#                         padding: 0;
#                     }
#                 </style>
#                 <script type="text/javascript">
#                     // initialize our variables
#                     var captchaReady = 0;
#                     var wFORMSReady = 0;
#
#                     // when wForms is loaded call this
#                     var wformsReadyCallback = function () {
#                         // using this var to denote if wForms is loaded
#                         wFORMSReady = 1;
#                         // call our recaptcha function which is dependent on both
#                         // wForms and an async call to google
#                         // note the meat of this function wont fire until both
#                         // wFORMSReady = 1 and captchaReady = 1
#                         onloadCallback();
#                     }
#                     var gCaptchaReadyCallback = function() {
#                         // using this var to denote if captcha is loaded
#                         captchaReady = 1;
#                         // call our recaptcha function which is dependent on both
#                         // wForms and an async call to google
#                         // note the meat of this function wont fire until both
#                         // wFORMSReady = 1 and captchaReady = 1
#                         onloadCallback();
#                     };
#
#                     // add event listener to fire when wForms is fully loaded
#                     document.addEventListener("wFORMSLoaded", wformsReadyCallback);
#
#                     var enableSubmitButton = function() {
#                         var submitButton = document.getElementById('submit_button');
#                         var explanation = document.getElementById('disabled-explanation');
#                         if (submitButton != null) {
#                             submitButton.removeAttribute('disabled');
#                             if (explanation != null) {
#                                 explanation.style.display = 'none';
#                             }
#                         }
#                     };
#                     var disableSubmitButton = function() {
#                         var submitButton = document.getElementById('submit_button');
#                         var explanation = document.getElementById('disabled-explanation');
#                         if (submitButton != null) {
#                             submitButton.disabled = true;
#                             if (explanation != null) {
#                                 explanation.style.display = 'block';
#                             }
#                         }
#                     };
#
#                     // call this on both captcha async complete and wforms fully
#                     // initialized since we can't be sure which will complete first
#                     // and we need both done for this to function just check that they are
#                     // done to fire the functionality
#                     var onloadCallback = function () {
#                         // if our captcha is ready (async call completed)
#                         // and wFORMS is completely loaded then we are ready to add
#                         // the captcha to the page
#                         if (captchaReady && wFORMSReady) {
#                             grecaptcha.render('g-recaptcha-render-div', {
#                                 'sitekey': '6LeISQ8UAAAAAL-Qe-lDcy4OIElnii__H_cEGV0C',
#                                 'theme': 'light',
#                                 'size': 'normal',
#                                 'callback': 'enableSubmitButton',
#                                 'expired-callback': 'disableSubmitButton'
#                             });
#                             var oldRecaptchaCheck = parseInt('0');
#                             if (oldRecaptchaCheck === -1) {
#                                 var standardCaptcha = document.getElementById("tfa_captcha_text");
#                                 standardCaptcha = standardCaptcha.parentNode.parentNode.parentNode;
#                                 standardCaptcha.parentNode.removeChild(standardCaptcha);
#                             }
#
#                             if (!wFORMS.instances['paging']) {
#                                 document.getElementById("g-recaptcha-render-div").parentNode.parentNode.parentNode.style.display = "block";
#                                 //document.getElementById("g-recaptcha-render-div").parentNode.parentNode.parentNode.removeAttribute("hidden");
#                             }
#                             document.getElementById("g-recaptcha-render-div").getAttributeNode('id').value = 'tfa_captcha_text';
#
#                             var captchaError = '';
#                             if (captchaError == '1') {
#                                 var errMsgText = 'The CAPTCHA was not completed successfully.';
#                                 var errMsgDiv = document.createElement('div');
#                                 errMsgDiv.id = "tfa_captcha_text-E";
#                                 errMsgDiv.className = "err errMsg";
#                                 errMsgDiv.innerText = errMsgText;
#                                 var loc = document.querySelector('.g-captcha-error');
#                                 loc.insertBefore(errMsgDiv, loc.childNodes[0]);
#
#                                 /* See wFORMS.behaviors.paging.applyTo for origin of this code */
#                                 if (wFORMS.instances['paging']) {
#                                     var b = wFORMS.instances['paging'][0];
#                                     var pp = base2.DOM.Element.querySelector(document, wFORMS.behaviors.paging.CAPTCHA_ERROR);
#                                     if (pp) {
#                                         var lastPage = 1;
#                                         for (var i = 1; i < 100; i++) {
#                                             if (b.behavior.isLastPageIndex(i)) {
#                                                 lastPage = i;
#                                                 break;
#                                             }
#                                         }
#                                         b.jumpTo(lastPage);
#                                     }
#                                 }
#                             }
#                         }
#                     };
#                 </script>
#                 <script src='https://www.google.com/recaptcha/api.js?onload=gCaptchaReadyCallback&render=explicit' async
#                         defer></script>
#                 <script type="text/javascript">
#                     document.addEventListener("DOMContentLoaded", function() {
#                         var warning = document.getElementById("javascript-warning");
#                         if (warning != null) {
#                             warning.parentNode.removeChild(warning);
#                         }
#                         var oldRecaptchaCheck = parseInt('0');
#                         if (oldRecaptchaCheck !== -1) {
#                             var explanation = document.getElementById('disabled-explanation');
#                             var submitButton = document.getElementById('submit_button');
#                             if (submitButton != null) {
#                                 submitButton.disabled = true;
#                                 if (explanation != null) {
#                                     explanation.style.display = 'block';
#                                 }
#                             }
#                         }
#                     });
#                 </script>
#                 <script type="text/javascript">
#         document.addEventListener("DOMContentLoaded", function(){
#             const FORM_TIME_START = Math.floor((new Date).getTime()/1000);
#             let formElement = document.getElementById("tfa_0");
#             if (null === formElement) {
#                 formElement = document.getElementById("0");
#             }
#             let appendJsTimerElement = function(){
#                 let formTimeDiff = Math.floor((new Date).getTime()/1000) - FORM_TIME_START;
#                 let cumulatedTimeElement = document.getElementById("tfa_dbCumulatedTime");
#                 if (null !== cumulatedTimeElement) {
#                     let cumulatedTime = parseInt(cumulatedTimeElement.value);
#                     if (null !== cumulatedTime && cumulatedTime > 0) {
#                         formTimeDiff += cumulatedTime;
#                     }
#                 }
#                 let jsTimeInput = document.createElement("input");
#                 jsTimeInput.setAttribute("type", "hidden");
#                 jsTimeInput.setAttribute("value", formTimeDiff.toString());
#                 jsTimeInput.setAttribute("name", "tfa_dbElapsedJsTime");
#                 jsTimeInput.setAttribute("id", "tfa_dbElapsedJsTime");
#                 jsTimeInput.setAttribute("autocomplete", "off");
#                 if (null !== formElement) {
#                     formElement.appendChild(jsTimeInput);
#                 }
#             };
#             if (null !== formElement) {
#                 if(formElement.addEventListener){
#                     formElement.addEventListener('submit', appendJsTimerElement, false);
#                 } else if(formElement.attachEvent){
#                     formElement.attachEvent('onsubmit', appendJsTimerElement);
#                 }
#             }
#         });
#     </script>
#
#     <link href="https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout.css?v=543" rel="stylesheet" type="text/css" />
#
#     <!--[if IE 8]>
#     <link href="https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout-ie8.css" rel="stylesheet" type="text/css" />
#     <![endif]-->
#     <!--[if IE 7]>
#     <link href="https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout-ie7.css" rel="stylesheet" type="text/css" />
#     <![endif]-->
#     <!--[if IE 6]>
#     <link href="https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout-ie6.css" rel="stylesheet" type="text/css" />
#     <![endif]-->
#     <link href="https://umbc.tfaforms.net/themes/get/2" rel="stylesheet" type="text/css" />
#     <link href="https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-jsonly.css?v=543" rel="alternate stylesheet" title="This stylesheet activated by javascript" type="text/css" />
#     <script type="text/javascript" src="https://umbc.tfaforms.net/wForms/3.10/js/wforms.js?v=543"></script>
#     <script type="text/javascript">
#         if(wFORMS.behaviors.prefill) wFORMS.behaviors.prefill.skip = true;
#     </script>
#     <script type="text/javascript" src="https://umbc.tfaforms.net/wForms/3.10/js/localization-en_US.js?v=543"></script>
#
# <!-- FORM: BODY SECTION -->
# <div class="wFormContainer"  >
#     <style type="text/css">
#                 #tfa_11,
#                 *[id^="tfa_11["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_11-D,
#                 *[id^="tfa_11["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_11-L,
#                 label[id^="tfa_11["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_12,
#                 *[id^="tfa_12["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_12-D,
#                 *[id^="tfa_12["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_12-L,
#                 label[id^="tfa_12["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_20,
#                 *[id^="tfa_20["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_20-D,
#                 *[id^="tfa_20["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_20-L,
#                 label[id^="tfa_20["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_24,
#                 *[id^="tfa_24["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_24-D,
#                 *[id^="tfa_24["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_24-L,
#                 label[id^="tfa_24["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_25,
#                 *[id^="tfa_25["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_25-D,
#                 *[id^="tfa_25["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_25-L,
#                 label[id^="tfa_25["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_26-L,
#                 label[id^="tfa_26["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_84,
#                 *[id^="tfa_84["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_84-D,
#                 *[id^="tfa_84["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_84-L,
#                 label[id^="tfa_84["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_375,
#                 *[id^="tfa_375["] {
#                     width: 270.44444px !important;
#                 }
#                 #tfa_375-D,
#                 *[id^="tfa_375["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_375-L,
#                 label[id^="tfa_375["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_331-L,
#                 label[id^="tfa_331["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_285-L,
#                 label[id^="tfa_285["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_766-L,
#                 label[id^="tfa_766["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_356-L,
#                 label[id^="tfa_356["] {
#                     width: 220px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_381,
#                 *[id^="tfa_381["] {
#                     width: 500.222222px !important;
#                 }
#                 #tfa_381-D,
#                 *[id^="tfa_381["][class~="field-container-D"] {
#                     width: auto !important;
#                 }
#
#                 #tfa_381-L,
#                 label[id^="tfa_381["] {
#                     width: 350px !important;
#                     min-width: 0px;
#                 }
#
#                 #tfa_381,
#                 *[id^="tfa_381["] {
#                     height: 120.222222px
#                 }
#                 #tfa_381-D,
#                 *[id^="tfa_381["][class~="field-container-D"] {
#                     height: auto !important;
#                 }
#                 #tfa_381-L,
#                 label[id^="tfa_381["],
#                 *[id^="tfa_381["][id$="-L"] {
#                     height: auto !important;
#                 }
#             </style><div class=""><div class="wForm" id="tfa_0-WRPR" dir="ltr">
# <div class="codesection" id="code-tfa_0">    <script type="text/javascript">
#
#       $(document).ready(function() {
#         makeSchoolpicker("369");
#         verifyFieldMatch(20,21) ;
#       });
#
#     </script>
#
# <style type="text/css">
#
# </style></div>
# <h3 class="wFormTitle" id="tfa_0-T">Integrated DPS Contact Us Form</h3>
# <form method="post" action="https://umbc.tfaforms.net/rest/responses/processor" class="hintsBelow labelsLeftAligned" id="tfa_0">
# <div id="tfa_23" class="section column group">
# <div id="tfa_416" class="section column group">
# <div class="oneField field-container-D    " id="tfa_11-D">
# <label id="tfa_11-L" for="tfa_11" class="label preField reqMark">First Name </label><div class="inputWrapper"><input type="text" id="tfa_11" name="tfa_11" value="" placeholder="" maxlength="40" aria-required="true" title="First Name " class="required"></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_12-D">
# <label id="tfa_12-L" for="tfa_12" class="label preField reqMark">Last Name </label><div class="inputWrapper"><input type="text" id="tfa_12" name="tfa_12" value="" placeholder="" maxlength="80" aria-required="true" title="Last Name " class="required"></div>
# </div>
# </div>
# <div class="oneField field-container-D    " id="tfa_20-D">
# <label id="tfa_20-L" for="tfa_20" class="label preField reqMark">Email Address</label><div class="inputWrapper"><input type="text" id="tfa_20" name="tfa_20" value="" placeholder="" maxlength="80" aria-required="true" title="Email Address" class="validate-email calc-emailA required"></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_24-D">
# <label id="tfa_24-L" for="tfa_24" class="label preField ">Street Address </label><div class="inputWrapper"><input type="text" id="tfa_24" name="tfa_24" value="" placeholder="" maxlength="255" title="Street Address " class=""></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_25-D">
# <label id="tfa_25-L" for="tfa_25" class="label preField ">City</label><div class="inputWrapper"><input type="text" id="tfa_25" name="tfa_25" value="" placeholder="" maxlength="40" title="City" class=""></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_26-D">
# <label id="tfa_26-L" for="tfa_26" class="label preField ">State or Province</label><div class="inputWrapper"><select id="tfa_26" name="tfa_26" title="State or Province" class=""><option value="">Please select...</option>
# <option value="tfa_419" id="tfa_419" class="">Alabama</option>
# <option value="tfa_420" id="tfa_420" class="">Alaska</option>
# <option value="tfa_421" id="tfa_421" class="">Alberta</option>
# <option value="tfa_422" id="tfa_422" class="">American Samoa</option>
# <option value="tfa_423" id="tfa_423" class="">Arizona</option>
# <option value="tfa_424" id="tfa_424" class="">Arkansas</option>
# <option value="tfa_425" id="tfa_425" class="">British Columbia</option>
# <option value="tfa_426" id="tfa_426" class="">California</option>
# <option value="tfa_427" id="tfa_427" class="">Colorado</option>
# <option value="tfa_428" id="tfa_428" class="">Connecticut</option>
# <option value="tfa_429" id="tfa_429" class="">Delaware</option>
# <option value="tfa_430" id="tfa_430" class="">District of Columbia</option>
# <option value="tfa_431" id="tfa_431" class="">Florida</option>
# <option value="tfa_432" id="tfa_432" class="">Georgia</option>
# <option value="tfa_433" id="tfa_433" class="">Guam</option>
# <option value="tfa_434" id="tfa_434" class="">Hawaii</option>
# <option value="tfa_435" id="tfa_435" class="">Idaho</option>
# <option value="tfa_436" id="tfa_436" class="">Illinois</option>
# <option value="tfa_437" id="tfa_437" class="">Indiana</option>
# <option value="tfa_438" id="tfa_438" class="">Iowa</option>
# <option value="tfa_439" id="tfa_439" class="">Kansas</option>
# <option value="tfa_440" id="tfa_440" class="">Kentucky</option>
# <option value="tfa_441" id="tfa_441" class="">Louisiana</option>
# <option value="tfa_442" id="tfa_442" class="">Maine</option>
# <option value="tfa_443" id="tfa_443" class="">Manitoba</option>
# <option value="tfa_444" id="tfa_444" class="">Marianna Islands</option>
# <option value="tfa_445" id="tfa_445" class="">Marshall Islands</option>
# <option value="tfa_446" id="tfa_446" class="">Maryland</option>
# <option value="tfa_447" id="tfa_447" class="">Massachusetts</option>
# <option value="tfa_448" id="tfa_448" class="">Michigan</option>
# <option value="tfa_449" id="tfa_449" class="">Micronesia</option>
# <option value="tfa_450" id="tfa_450" class="">Minnesota</option>
# <option value="tfa_451" id="tfa_451" class="">Minor Outlaying Islands</option>
# <option value="tfa_452" id="tfa_452" class="">Mississippi</option>
# <option value="tfa_453" id="tfa_453" class="">Missouri</option>
# <option value="tfa_454" id="tfa_454" class="">Montana</option>
# <option value="tfa_455" id="tfa_455" class="">Nebraska</option>
# <option value="tfa_456" id="tfa_456" class="">Nevada</option>
# <option value="tfa_457" id="tfa_457" class="">New Brunswick</option>
# <option value="tfa_458" id="tfa_458" class="">Newfoundland and Labrador</option>
# <option value="tfa_459" id="tfa_459" class="">New Hampshire</option>
# <option value="tfa_460" id="tfa_460" class="">New Jersey</option>
# <option value="tfa_461" id="tfa_461" class="">New Mexico</option>
# <option value="tfa_462" id="tfa_462" class="">New York</option>
# <option value="tfa_463" id="tfa_463" class="">North Carolina</option>
# <option value="tfa_464" id="tfa_464" class="">North Dakota</option>
# <option value="tfa_465" id="tfa_465" class="">Northwest Territories</option>
# <option value="tfa_466" id="tfa_466" class="">Nova Scotia</option>
# <option value="tfa_467" id="tfa_467" class="">Nunavut</option>
# <option value="tfa_468" id="tfa_468" class="">Ohio</option>
# <option value="tfa_469" id="tfa_469" class="">Oklahoma</option>
# <option value="tfa_470" id="tfa_470" class="">Ontario</option>
# <option value="tfa_471" id="tfa_471" class="">Oregon</option>
# <option value="tfa_472" id="tfa_472" class="">Palau</option>
# <option value="tfa_473" id="tfa_473" class="">Pennsylvania</option>
# <option value="tfa_474" id="tfa_474" class="">Prince Edward Island</option>
# <option value="tfa_475" id="tfa_475" class="">Puerto Rico</option>
# <option value="tfa_476" id="tfa_476" class="">Quebec</option>
# <option value="tfa_477" id="tfa_477" class="">Rhode Island</option>
# <option value="tfa_478" id="tfa_478" class="">Saskatchewan</option>
# <option value="tfa_479" id="tfa_479" class="">South Carolina</option>
# <option value="tfa_480" id="tfa_480" class="">South Dakota</option>
# <option value="tfa_481" id="tfa_481" class="">Tennessee</option>
# <option value="tfa_482" id="tfa_482" class="">Texas</option>
# <option value="tfa_483" id="tfa_483" class="">Utah</option>
# <option value="tfa_484" id="tfa_484" class="">Vermont</option>
# <option value="tfa_485" id="tfa_485" class="">Virginia</option>
# <option value="tfa_486" id="tfa_486" class="">Virgin Islands</option>
# <option value="tfa_487" id="tfa_487" class="">Washington</option>
# <option value="tfa_488" id="tfa_488" class="">West Virginia</option>
# <option value="tfa_489" id="tfa_489" class="">Wisconsin</option>
# <option value="tfa_490" id="tfa_490" class="">Wyoming</option>
# <option value="tfa_491" id="tfa_491" class="">Yukon</option></select></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_84-D">
# <label id="tfa_84-L" for="tfa_84" class="label preField ">Zip/Postal Code </label><div class="inputWrapper"><input type="text" id="tfa_84" name="tfa_84" value="" placeholder="" maxlength="10" title="Zip/Postal Code " class=""></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_375-D">
# <label id="tfa_375-L" for="tfa_375" class="label preField ">Mobile Phone </label><div class="inputWrapper"><input type="text" id="tfa_375" name="tfa_375" value="" placeholder="" title="Mobile Phone " class=""></div>
# </div>
# </div>
# <div id="tfa_283" class="section column group">
# <div id="tfa_417" class="section column empty group"></div>
# <div class="oneField field-container-D    " id="tfa_331-D">
# <label id="tfa_331-L" for="tfa_331" class="label preField reqMark">Anticipated Major or Program </label><div class="inputWrapper"><select id="tfa_331" name="tfa_331" title="Anticipated Major or Program " aria-required="true" class="required"><option value="">Please select...</option>
# <option value="tfa_754" id="tfa_754" class="">Biotechnology</option>
# <option value="tfa_834" id="tfa_834" class="">Community Leadership</option>
# <option value="tfa_755" id="tfa_755" class="">Cybersecurity</option>
# <option value="tfa_823" id="tfa_823" class="">Data Science</option>
# <option value="tfa_762" id="tfa_762" class="">Engineering Management</option>
# <option value="tfa_826" id="tfa_826" class="">Entrepreneurship, Innovation &amp; Leadership</option>
# <option value="tfa_763" id="tfa_763" class="">Geographic Information Systems</option>
# <option value="tfa_756" id="tfa_756" class="">Health Information Technology</option>
# <option value="tfa_761" id="tfa_761" class="">I/O Psychology</option>
# <option value="tfa_765" id="tfa_765" class="">Instructional Systems Development</option>
# <option value="tfa_827" id="tfa_827" class="">Integrated Product Development &amp; Manufacturing</option>
# <option value="tfa_828" id="tfa_828" class="">Project Management Certificate</option>
# <option value="tfa_764" id="tfa_764" class="">Systems Engineering</option>
# <option value="tfa_818" id="tfa_818" class="">Technical Management</option></select></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_285-D">
# <label id="tfa_285-L" for="tfa_285" class="label preField ">Anticipated Start Date&nbsp;</label><div class="inputWrapper"><select id="tfa_285" name="tfa_285" title="Anticipated Start Date " class=""><option value="">Please select...</option>
# <option value="tfa_815" id="tfa_815" class="">Fall 2019</option>
# <option value="tfa_829" id="tfa_829" class="">Spring 2020</option>
# <option value="tfa_830" id="tfa_830" class="">Fall 2020</option>
# <option value="tfa_835" id="tfa_835" class="">Spring 2021</option>
# <option value="tfa_836" id="tfa_836" class="">Fall 2021</option>
# <option value="tfa_753" id="tfa_753" class="">Unknown</option></select></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_766-D">
# <label id="tfa_766-L" for="tfa_766" class="label preField ">Campus of Choice</label><div class="inputWrapper"><select id="tfa_766" name="tfa_766" title="Campus of Choice" class=""><option value="">Please select...</option>
# <option value="tfa_768" id="tfa_768" class="">Main Campus</option>
# <option value="tfa_767" id="tfa_767" class="">Shady Grove</option></select></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_356-D">
# <label id="tfa_356-L" for="tfa_356" class="label preField ">How did you hear about us?*</label><div class="inputWrapper"><select id="tfa_356" name="tfa_356" title="How did you hear about us?*" class=""><option value="">Please select...</option>
# <option value="tfa_795" id="tfa_795" class="">Email</option>
# <option value="tfa_797" id="tfa_797" class="">Friend/Associate</option>
# <option value="tfa_800" id="tfa_800" class="">Internet Search</option>
# <option value="tfa_802" id="tfa_802" class="">Social Media</option>
# <option value="tfa_799" id="tfa_799" class="">Internet Radio</option>
# <option value="tfa_820" id="tfa_820" class="">MPT</option>
# <option value="tfa_821" id="tfa_821" class="">Theater Ad</option>
# <option value="tfa_798" id="tfa_798" class="">Individual Visit</option>
# <option value="tfa_801" id="tfa_801" class="">Publication</option>
# <option value="tfa_803" id="tfa_803" class="">Blog</option>
# <option value="tfa_804" id="tfa_804" class="">Infographic</option>
# <option value="tfa_796" id="tfa_796" class="">Flyer/Poster</option>
# <option value="tfa_805" id="tfa_805" class="">Video</option>
# <option value="tfa_806" id="tfa_806" class="">Other</option></select></div>
# </div>
# <div class="oneField field-container-D  labelsAbove  " id="tfa_381-D">
# <label id="tfa_381-L" for="tfa_381" class="label preField "><span id="j_id0:j_id6"><span id="j_id0:j_id6:j_id7:j_id45"><span id="j_id0:j_id6:j_id7:form:j_id50:28:j_id59"><span id="LaDescription" title="">Questions/Comments</span></span></span></span></label><br><div class="inputWrapper"><textarea id="tfa_381" name="tfa_381" title="Questions/Comments" class=""></textarea></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_807-D">
# <label id="tfa_807-L" for="tfa_807" class="label preField ">Program URL</label><div class="inputWrapper"><input type="text" id="tfa_807" name="tfa_807" value="" placeholder="" title="Program URL" class=""></div>
# </div>
# </div>
# <div class="oneField field-container-D    " id="tfa_808-D">
# <label id="tfa_808-L" for="tfa_808" class="label preField ">Google UserID</label><div class="inputWrapper"><input type="text" id="tfa_808" name="tfa_808" value="" placeholder="" title="Google UserID" class=""></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_809-D">
# <label id="tfa_809-L" for="tfa_809" class="label preField ">Program Coordinator</label><div class="inputWrapper"><select id="tfa_809" name="tfa_809" title="Program Coordinator" class=""><option value="">Please select...</option>
# <option value="tfa_810" id="tfa_810" class="">Lisa Gambino - 00550000006H4P4</option>
# <option value="tfa_811" id="tfa_811" class="">Kim Edmonds - 00550000006H4PO</option>
# <option value="tfa_812" id="tfa_812" class="">Renee Eisenhuth - 00550000006H4Pi</option>
# <option value="tfa_813" id="tfa_813" class="">Rickeysha Jones - 00550000006FHKj</option>
# <option value="tfa_814" id="tfa_814" class="">Nancy Clements - 00550000006H4Pd</option>
# <option value="tfa_824" id="tfa_824" class="">Sonya Crosby - 005500000063CBi</option>
# <option value="tfa_825" id="tfa_825" class="">Christine Osazuwa - 005500000061wNR</option>
# <option value="tfa_833" id="tfa_833" class="">Faith Dinh - 0052J000007mytT</option></select></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_816-D">
# <label id="tfa_816-L" for="tfa_816" class="label preField ">Program Coordinator Email</label><div class="inputWrapper"><input type="text" id="tfa_816" name="tfa_816" value="" placeholder="" title="Program Coordinator Email" class=""></div>
# </div>
# <div class="oneField field-container-D    " id="tfa_817-D">
# <label id="tfa_817-L" for="tfa_817" class="label preField ">Email Body</label><div class="inputWrapper"><textarea id="tfa_817" name="tfa_817" title="Email Body" class=""></textarea></div>
# </div>
# <div class="htmlSection" id="tfa_822"><div class="htmlContent" id="tfa_822-HTML">Buffer text for captcha</div></div>
# <input type="hidden" id="tfa_831" name="tfa_831" value="" class=""><input type="hidden" id="tfa_832" name="tfa_832" value="" class=""><div class="actions" id="tfa_0-A">
# <div id="google-captcha" style="display: none">
# <br><div class="captcha">
# <div class="oneField">
# <div class="g-recaptcha" id="g-recaptcha-render-div"></div>
# <div class="g-captcha-error"></div>
# <br>
# </div>
# <div class="captchaHelp">reCAPTCHA helps prevent automated form spam.<br>
# </div>
# <div id="disabled-explanation" class="captchaHelp" style="display: none">The submit button will be disabled until you complete the CAPTCHA.</div>
# </div>
# </div>
# <input type="submit" data-label="Submit" class="primaryAction" id="submit_button" value="Submit">
# </div>
# <div style="clear:both"></div>
# <input type="hidden" value="27-95e233e172672c814ee98149c29add85" name="tfa_dbCounters" id="tfa_dbCounters" autocomplete="off"><input type="hidden" value="217767" name="tfa_dbFormId" id="tfa_dbFormId"><input type="hidden" value="" name="tfa_dbResponseId" id="tfa_dbResponseId"><input type="hidden" value="03e0df6763eb14a0589d7befd8c0429f" name="tfa_dbControl" id="tfa_dbControl"><input type="hidden" value="1560192958" name="tfa_dbTimeStarted" id="tfa_dbTimeStarted" autocomplete="off"><input type="hidden" value="13" name="tfa_dbVersionId" id="tfa_dbVersionId"><input type="hidden" value="" name="tfa_switchedoff" id="tfa_switchedoff">
# </form>
# </div></div>
# <div class="wFormFooter">
#   <p class="supportInfo" >
#         <a href="https://umbc.tfaforms.net/forms/help/217767" target="new"
#        style="font-size: 0.7em;"  >
#       Need assistance with this form?    </a>
#
#
#       </p>
#  </div>
# </div>	</div>
#
#
# 	<script>
# 	$('aside #tfa_0').submit(function() {
# 	  ga('send', 'event', 'inquiry', 'Sidebar Inquiry', 'Data Science');
# 	});
# 	</script>
# 	<script>
# 	$('aside #tfa_0').submit(function() {
# 	  ga('rollup.send', 'event', 'inquiry', 'Sidebar Inquiry', 'Data Science');
# 	});
# 	</script>
# </aside>
#
#                   <aside class="five columns add-bottom">
# <dt style="text-align:center">
# <a class="btn" href="http://gritinaction.umbc.edu/" target="_blank">
# Visit our Blog
# </a>
# </dt>
# </aside>
#
# <aside  class="five columns add-bottom">
# <center>
#      <a href="http://twitter.com/umbc_dps" target="_blank"><img src="images/twitter.png" alt="twitter" width="30" height="30"></a>
#
#      <a href="http://facebook.com/UMBCProfessionalGradPrograms" target="_blank"><img src="images/facebook.png" width="30" height="30" alt="facebook"></a>
#
#      <a href="https://www.youtube.com/channel/UCLVsMMEHLDtrRaDaZrkiSNA" target="_blank"><img src="images/youtube.png" alt="YouTube"  width="30" height="30"></a>
#
#      <a href="https://www.linkedin.com/company/7835" target="_blank"><img src="images/linkedin.png" alt="YouTube"  width="30" height="30"></a>
#
#      <a href="http://my.umbc.edu/groups/dps" target="_blank"><img src="images/myUMBC.png" alt="myUMBC" height="30"></a>
# </center>
# </aside>
# </div>  <!-- END SIDEBAR -->
#
#   <!-- Footer -->
# <footer class="clearfix" id="site-footer">
#
# <div class="full-width column add-bottom">
#   <h3>Data Science Job Outlook </h3>
# <p>Data analysis is a quickly-growing field and demand for experienced data science professionals will only continue to grow. According to the Bureau of Labor Statistics, data analyst jobs are expected to increase by nearly 20% between 2014-2024 and the Baltimore-Washington metro area has seen a disproportionate rise in the number of employers seeking candidates with expertise in data science.
# <br><br>Job opportunities available to professionals with a Data Science degree include:</p>
# <ul>
#     <li>Operations Research Analyst</li>
#     <li>Market Research Analyst</li>
#     <li>Investment Data Analyst</li>
#     <li>Business Intelligence Analyst</li>
#     <li>And much more</li>
# </ul>
#     </div>
#
#   <!-- Footer -->
#   <br clear="all">
# <p align="center" style="border-top:2px #E9AB13 solid">
# <br />
#
# © <script>document.write(new Date().getFullYear())</script> UMBC <a href="http://umbc.edu/dps" target="_blank">Division of Professional Studies</a> · 1000 Hilltop Circle, Sherman Hall East 4th Floor, Baltimore, MD 21250 · 410-455-2336 · <a href="mailto:dps@umbc.edu">dps@umbc.edu</a>
#
# </p>
#   </footer>
#   <!-- END footer -->
#   <!-- END container -->
#
#
# <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script>
# <script src="//code.jquery.com/ui/1.11.4/jquery-ui.js"></script>
#
# <script src="js/scripts.js"></script>
# <script src="js/jquery.cbpFWSlider.js"></script>
# <script src="js/jquery.magnific-popup.js"></script>
# <script src="js/popup.js"></script>
#
#
#
#  <script>
# $( function() {
#     var isPaused = false;
#     $( '#cbp-fwslider' ).cbpFWSlider()
#       .on({
#         mouseenter: function() { isPaused = true; },
#         mouseleave: function() { isPaused = false; }
#                         });
#
#     setInterval(function() {
#         if (isPaused) return; // do nothing when paused
#
#         if(jQuery('.cbp-fwnext').css('display') != 'none')
#             jQuery('.cbp-fwnext').click();
#         else
#             jQuery('.cbp-fwdots span:first-child').click();
#     }, 5000);
# });
# </script>
#
# <script>
# $('#cbp-fwslider').on('click', function() {
#   ga('send', 'event', 'slider', 'slide', {'nonInteraction': 1});
# });
# $('#slide1').on('click', function() {
#   var slideID = document.getElementById('slide1');
#   var slideLink = slideID.getElementsByTagName('a')[0];
#   var slideURL = slideLink.href;
#   ga('send', 'event', 'slider', 'slide1', slideURL);
# });
# $('#slide2').on('click', function() {
#   var slideID = document.getElementById('slide2');
#   var slideLink = slideID.getElementsByTagName('a')[0];
#   var slideURL = slideLink.href;
#   ga('send', 'event', 'slider', 'slide2', slideURL);
# });
# $('#slide3').on('click', function() {
#   var slideID = document.getElementById('slide3');
#   var slideLink = slideID.getElementsByTagName('a')[0];
#   var slideURL = slideLink.href;
#   ga('send', 'event', 'slider', 'slide3', slideURL);
# });
#
# $('#slide4').on('click', function() {
#   var slideID = document.getElementById('slide4');
#   var slideLink = slideID.getElementsByTagName('a')[0];
#   var slideURL = slideLink.href;
#   ga('send', 'event', 'slider', 'slide4', slideURL);
# });
#
# $('#slide5').on('click', function() {
#   var slideID = document.getElementById('slide5');
#   var slideLink = slideID.getElementsByTagName('a')[0];
#   var slideURL = slideLink.href;
#   ga('send', 'event', 'slider', 'slide5', slideURL);
# });
#
# $('#slide6').on('click', function() {
#   var slideID = document.getElementById('slide6');
#   var slideLink = slideID.getElementsByTagName('a')[0];
#   var slideURL = slideLink.href;
#   ga('send', 'event', 'slider', 'slide6', slideURL);
# });
#
# $(".cbp-fwnext").on('hover', function() {
#   ga('send', 'event', 'slider', 'button', 'next');
# });
# $(".cbp-fwprev").on('hover', function() {
#   ga('send', 'event', 'slider', 'button', 'previous');
# });
# $(".cbp-fwdots").on('hover', function() {
#   ga('send', 'event', 'slider', 'button', 'dots');
# });
# </script>
#
#
#
# <script>
# $(document).ready(function () {
# 	ytTracker.init();
# });
# </script>
#
# <script>
# /* Diable jQuery CSS */
# $('link[href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.8.18/themes/smoothness/jquery-ui.css"]').prop('disabled',true);
#
# /* Set Program */
# $('select#tfa_331').find('option').each(function(){
#          if($(this).text() == 'Data Science')
#             this.selected = true;
#     });
#
# /* Set Campus */
# $('select#tfa_766').find('option').each(function(){
#          if($(this).text() == 'Main Campus')
#             this.selected = true;
#     });
#
#
# /* Set Program Coordinator */
# $('select#tfa_809').find('option').each(function(){
#          if($(this).text() == 'Faith Dinh - 0052J000007mytT')
#             this.selected = true;
#     });
#
# /* Set Program Coordinator Email */
# $("#tfa_816").attr("value", 'faithdinh@umbc.edu');
#
# /* Set Program URL */
# $("#tfa_807").attr("value", 'datascience');
#
# /*Set Email Body */
# $("#tfa_817").val("UMBC's Data Science program is built around a core set of courses wherein students will develop an in-depth understanding of the basic computing principles behind data science, to include but not limited to data ingestion, curation and cleaning and the 4Vs of data science: Volume, Variety, Velocity, Veracity, as well as the implicit 5th V -- Value.  Through applying principles of data science to the analysis of problems within specific domains expressed through the program pathways, students will gain practical, real world industry relevant experience.");
#
# /*Set Pardot Campaign Form Handler */
# $("#tfa_831").attr("value", 'https://go.pardot.com/l/375302/2018-04-02/5mgy39');
#
# /* Send Google ID to Salesforce */
# ga(function(tracker) {
#   var clientId = tracker.get('clientId');
#   $("#tfa_808").attr("value", clientId)
# });
# </script>
# </body>
#
# </html>

# %%
# LET'S DO SOME WEBCRAWLING
from urllib.request import urlopen
import re
# conntect to a url
website = urlopen('http://datascience.umbc.edu/')
# read htmlcode
html = website.read().decode('utf-8')

#use re.findall to get all the links
links = re.findall('"((http|ftp)s?://.*?)"', html)

# print links
for onelink in links:
    print(onelink)
# Out:
# ('https://www.facebook.com/tr?id=474030342731967&ev=PageView&noscript=1', 'http')
# ('https://analytics.twitter.com/i/adsct?txn_id=l4pxn&p_id=Twitter', 'http')
# ('http://www.umbc.edu/datascience/index/', 'http')
# ('http://www.umbc.edu/biotech/images/bk.jpg', 'http')
# ('http://umbc.edu', 'http')
# ('http://umbc.edu', 'http')
# ('http://umbc.edu/siteindex', 'http')
# ('http://my.umbc.edu', 'http')
# ('http://my.umbc.edu/events', 'http')
# ('http://umbc.edu/search/directory', 'http')
# ('http://about.umbc.edu/visitors-guide/campus-map', 'http')
# ('http://www.umbc.edu/stats/searchthru/', 'http')
# ('http://about.umbc.edu/visitors-guide/directions/', 'http')
# ('https://gradschool.umbc.edu/admissions/apply/', 'http')
# ('http://cyber.umbc.edu/images/1.jpg', 'http')
# ('http://gradschool.umbc.edu/admissions/apply', 'http')
# ('http://gradschool.umbc.edu/admissions/apply', 'http')
# ('https://www.youtube.com/watch?v=rAe6FbE3jb0', 'http')
# ('http://www.umbc.edu/cyber/images/2.jpg', 'http')
# ('https://www.youtube.com/watch?v=rAe6FbE3jb0', 'http')
# ('https://www.youtube.com/watch?v=rAe6FbE3jb0', 'http')
# ('http://gritinaction.umbc.edu/mps-degree/', 'http')
# ('https://engm.umbc.edu/images/4.png', 'http')
# ('http://gritinaction.umbc.edu/mps-degree/', 'http')
# ('http://gritinaction.umbc.edu/mps-degree/', 'http')
# ('http://regional.umbc.edu', 'http')
# ('http://gritinaction.umbc.edu/mps-degree/', 'http')
# ('http://openhouse.umbc.edu/shadygrove?utm_campaign=openhouse_summer19&utm_source=umbc.edu&utm_medium=referral&utm_content=datascience_sidebar', 'http')
# ('http://gradschool.umbc.edu/admissions/apply', 'http')
# ('http://shadygrove.umbc.edu/datascience', 'http')
# ('http://regional.umbc.edu', 'http')
# ('https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout.css?v=543', 'http')
# ('https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout-ie8.css', 'http')
# ('https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout-ie7.css', 'http')
# ('https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-layout-ie6.css', 'http')
# ('https://umbc.tfaforms.net/themes/get/2', 'http')
# ('https://umbc.tfaforms.net/form-builder/4.4.0/css/wforms-jsonly.css?v=543', 'http')
# ('https://umbc.tfaforms.net/wForms/3.10/js/wforms.js?v=543', 'http')
# ('https://umbc.tfaforms.net/wForms/3.10/js/localization-en_US.js?v=543', 'http')
# ('https://umbc.tfaforms.net/rest/responses/processor', 'http')
# ('https://umbc.tfaforms.net/forms/help/217767', 'http')
# ('http://gritinaction.umbc.edu/', 'http')
# ('http://twitter.com/umbc_dps', 'http')
# ('http://facebook.com/UMBCProfessionalGradPrograms', 'http')
# ('https://www.youtube.com/channel/UCLVsMMEHLDtrRaDaZrkiSNA', 'http')
# ('https://www.linkedin.com/company/7835', 'http')
# ('http://my.umbc.edu/groups/dps', 'http')
# ('http://umbc.edu/dps', 'http')
# ('http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js', 'http')
# ('https://ajax.googleapis.com/ajax/libs/jqueryui/1.8.18/themes/smoothness/jquery-ui.css', 'http')

# %% [raw]
# # EMAIL CRAWLING!!!
# website = urlopen('https://dps.umbc.edu/staffdirectory')
# # read htmlcode
# html = website.read().decode('utf-8')
#
# #use re.findall to get all the links
# email_addresses = re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", html)
#
# # print email_addresses
# for an_email_address in email_addresses:
#     print(an_email_address)
